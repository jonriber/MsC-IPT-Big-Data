# %% [markdown]
# <div style="border: 1px solid black">
# <b><center><font size="4">Information Retrieval</font></center></b>
#
# <b><center><font size="3">Framewords</font></center></b>
#
# <b><center><font size="2">2 - Redis</font></center></b>
# </div>

# %% [markdown]
# **Notebook Developed by**: [Ricardo Campos](http://www.ccc.ipt.pt/~ricardo)<br>
# **email:**  ricardo.campos@ubi.pt<br>
# **Affiliation:** *Assistant Professor* @ [University of Beira Interior](http://www.ubi.pt);
# *Researcher* @ [LIAAD](https://www.inesctec.pt/en/centres/liaad)-[INESC TEC](https://www.inesctec.pt/en)
#
# <hr>
#
# <p><a href="2Redis.ipynb" title="Download Notebook" download><img src="https://www.di.ubi.pt/~rcampos/assets/img_tutorials/download.jpg" align = "left" width="50" height="50" alt="Download Notebook"></a></p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# <hr>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Redis" data-toc-modified-id="Redis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Redis</a></span><ul class="toc-item"><li><span><a href="#When-would-we-use-Redis?" data-toc-modified-id="When-would-we-use-Redis?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>When would we use Redis?</a></span></li><li><span><a href="#What-is-Redis-used-for?" data-toc-modified-id="What-is-Redis-used-for?-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>What is Redis used for?</a></span></li><li><span><a href="#Can-Redis-be-used-with-Elastic-Search?" data-toc-modified-id="Can-Redis-be-used-with-Elastic-Search?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Can Redis be used with Elastic Search?</a></span></li></ul></li><li><span><a href="#Installation" data-toc-modified-id="Installation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Installation</a></span><ul class="toc-item"><li><span><a href="#Docker" data-toc-modified-id="Docker-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Docker</a></span><ul class="toc-item"><li><span><a href="#Installing-Docker" data-toc-modified-id="Installing-Docker-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Installing Docker</a></span></li><li><span><a href="#redis" data-toc-modified-id="redis-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>redis</a></span></li></ul></li></ul></li><li><span><a href="#Play-with-Redis-on-Python" data-toc-modified-id="Play-with-Redis-on-Python-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Play with Redis on Python</a></span><ul class="toc-item"><li><span><a href="#Hello-World-Example" data-toc-modified-id="Hello-World-Example-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Hello World Example</a></span><ul class="toc-item"><li><span><a href="#Connect-to-Redis" data-toc-modified-id="Connect-to-Redis-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Connect to Redis</a></span></li><li><span><a href="#Indexing" data-toc-modified-id="Indexing-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Indexing</a></span></li><li><span><a href="#Get" data-toc-modified-id="Get-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Get</a></span></li><li><span><a href="#Exists" data-toc-modified-id="Exists-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Exists</a></span></li><li><span><a href="#Delete-key-value-pair" data-toc-modified-id="Delete-key-value-pair-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Delete key-value pair</a></span></li><li><span><a href="#Delete-database" data-toc-modified-id="Delete-database-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Delete database</a></span></li><li><span><a href="#Persistently-Storage" data-toc-modified-id="Persistently-Storage-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Persistently Storage</a></span></li></ul></li><li><span><a href="#Index-Different-Types-of-Data" data-toc-modified-id="Index-Different-Types-of-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Index Different Types of Data</a></span></li><li><span><a href="#Redisearch" data-toc-modified-id="Redisearch-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Redisearch</a></span><ul class="toc-item"><li><span><a href="#Traditional-Search" data-toc-modified-id="Traditional-Search-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Traditional Search</a></span><ul class="toc-item"><li><span><a href="#Indexing" data-toc-modified-id="Indexing-3.3.1.1"><span class="toc-item-num">3.3.1.1&nbsp;&nbsp;</span>Indexing</a></span></li><li><span><a href="#Searching" data-toc-modified-id="Searching-3.3.1.2"><span class="toc-item-num">3.3.1.2&nbsp;&nbsp;</span>Searching</a></span></li><li><span><a href="#Quizzes" data-toc-modified-id="Quizzes-3.3.1.3"><span class="toc-item-num">3.3.1.3&nbsp;&nbsp;</span>Quizzes</a></span><ul class="toc-item"><li><span><a href="#Big-Bang-Theory" data-toc-modified-id="Big-Bang-Theory-3.3.1.3.1"><span class="toc-item-num">3.3.1.3.1&nbsp;&nbsp;</span>Big Bang Theory</a></span></li><li><span><a href="#Publico" data-toc-modified-id="Publico-3.3.1.3.2"><span class="toc-item-num">3.3.1.3.2&nbsp;&nbsp;</span>Publico</a></span></li></ul></li></ul></li><li><span><a href="#Vector-Similarity-Search" data-toc-modified-id="Vector-Similarity-Search-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Vector Similarity Search</a></span><ul class="toc-item"><li><span><a href="#Indexing" data-toc-modified-id="Indexing-3.3.2.1"><span class="toc-item-num">3.3.2.1&nbsp;&nbsp;</span>Indexing</a></span></li><li><span><a href="#Searching" data-toc-modified-id="Searching-3.3.2.2"><span class="toc-item-num">3.3.2.2&nbsp;&nbsp;</span>Searching</a></span><ul class="toc-item"><li><span><a href="#KNN" data-toc-modified-id="KNN-3.3.2.2.1"><span class="toc-item-num">3.3.2.2.1&nbsp;&nbsp;</span>KNN</a></span></li><li><span><a href="#Range" data-toc-modified-id="Range-3.3.2.2.2"><span class="toc-item-num">3.3.2.2.2&nbsp;&nbsp;</span>Range</a></span></li><li><span><a href="#Hybrid" data-toc-modified-id="Hybrid-3.3.2.2.3"><span class="toc-item-num">3.3.2.2.3&nbsp;&nbsp;</span>Hybrid</a></span></li></ul></li><li><span><a href="#Quizzes" data-toc-modified-id="Quizzes-3.3.2.3"><span class="toc-item-num">3.3.2.3&nbsp;&nbsp;</span>Quizzes</a></span><ul class="toc-item"><li><span><a href="#Wikipedia-(Hugging-Face-Embeddings)" data-toc-modified-id="Wikipedia-(Hugging-Face-Embeddings)-3.3.2.3.1"><span class="toc-item-num">3.3.2.3.1&nbsp;&nbsp;</span>Wikipedia (Hugging Face Embeddings)</a></span></li><li><span><a href="#Wikipedia-(OpenAI-Embeddings)" data-toc-modified-id="Wikipedia-(OpenAI-Embeddings)-3.3.2.3.2"><span class="toc-item-num">3.3.2.3.2&nbsp;&nbsp;</span>Wikipedia (OpenAI Embeddings)</a></span></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#Bibliography" data-toc-modified-id="Bibliography-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Bibliography</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#
# ## Objetivos de aprendizagem  <a class="tocSkip">
#
# No final deste notebook o aluno deverá saber trabalhar com sistemas de bases de dados nosql redis com vista à indexação de dados e à recuperação de informação, com recurso a métodos tradicionais de pesquisa e à utilização de embeddings obtidos a partir da framework HuggingFace e OpenAI.
#
#
# ## Learning Objectives  <a class="tocSkip">
#
# When concluding this notebook, the student should know how to operate with nosql databases such as redis to index and retrieve textual data, through traditional IR techniques and embeddings vectors obtained from HuggingFace and OpenAI </div>

# %% [markdown]
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#
# ## Sumário  <a class="tocSkip">
# ### Frameworks de indexação e recuperação de informação <a class="tocSkip">
#
# Introdução dos alunos ao Redis.
# - O que é o Redis?
# - Instalação
# - Indexação
# - Recuperação de informação com recurso a métodos tradicionais e a embeddings obtidos a partir do HuggingFace e da OpenAI
# - Uso do Redis-Insight para acesso à informação indexada
# - Casos práticos de indexação e recuperação de informação (big bang theory; jornal público; wikipedia)
#
# ## Class Summary  <a class="tocSkip">
# ### Indexing and retrieval frameworks <a class="tocSkip">
# Introduction to Redis.
# - What is Redis?
# - Installation
# - Indexing
# - Information retrieval using traditional methods and embedding vectors obtained from HugginFace and OpenAI
# - Use of Redis-Insight to access indexed information
# - Practical cases of indexing and information retrieval (big bang theory; jornal público; wikipedia)
#
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Redis

# %% [markdown]
# Redis (stands for Remote Dictionary Service) is `an open-source, networked, in-memory, key-value data store with optional durability`.
# - **Open source** - Anyone can inspect Redis’ code or contribute to the [project](https://github.com/redis/redis).
# - **Networked** - Redis uses the client-server model, in which communication between clients and servers happens over a network. In this tutorial, both a client and server are run on a single machine. In production systems, a load-balanced, multinode Redis cluster (of servers) will service requests from several clients.
# - **In-memory** — Redis stores data in primary computer memory (i.e., RAM). Data stored in RAM is more quickly accessed than data stored in slower (secondary) memory such as on disk. This is what makes Redis fast and suitable for applications that require low-latency access to data (e.g., caching).
# - **Key-value data store** - Redis is a glorified dictionary. The main operations supported are setting keys with their values and getting values using their associated keys, and other variations of this
# - **Optional durability** -  being an in-memory data store, isn’t fully durable by default. There is a chance that some of the data that was successfully written to Redis may be lost in the event the Redis host fails. Notice that RAM is volatile, meaning that if the power is lost, well, so too is what’s stored in RAM. This is undesirable for anyone who wants to build systems that maximize performance without compromising durability. Fortunately, Redis provides several persistence options with different performance durability profiles, including an option that affords full durability.

# %% [markdown]
# Redis has a client-server architecture and uses a request-response model. This means that you (the client) connect to a Redis server through TCP connection, on port 6379 by default. You request some action (like some form of reading, writing, getting, setting, or updating), and the server serves you back a response.

# %% [markdown]
# Broadly speaking, there are many parallels you can draw between a Python dictionary and what Redis is and does:
# - A Redis database holds key:value pairs and supports commands such as GET, SET, and DEL, as well as several hundred additional commands.
# - Redis keys are always strings.
# - Redis values may be a number of different data types.
# - Many Redis commands operate in constant O(1) time, just like retrieving a value from a Python dict or any hash table.

# %% [markdown]
# <hr>

# %% [markdown]
# ### When would we use Redis?

# %% [markdown]
# Redis is commonly used in web stacks as the `cache` service accessed by the API. For example, the client (browser) will make a request to the API (server) for some common piece of data, like “Top 10 Product Categories”. Rather than the API going directly to the database, executing a potentially long running query statement (depending on how well your database schema is structured) and awaiting the result, we can populate both the Redis key-value store and the database with identical information.
#
# In this scenario, the database is used as the “true data source” and Redis is used as the lightweight, fast lookup for commonly accessed data — like Top Categories. If the client requested all information about a particular, unpopular Product ID, for instance, we probably should not store all of this data in-memory with Redis and eat up all of our server’s RAM; instead, we would just execute a slower database query to service the request.

# %% [markdown]
# ### What is Redis used for?

# %% [markdown]
# Even though Redis could be used as your primary Database it's usually not what it is used for. Redis is usually used as a cache, which is a fast way to store data in memory and as a message queue.

# %% [markdown]
# ### Can Redis be used with Elastic Search?

# %% [markdown]
# Redis and Elasticsearch are two distinct and complementary technologies that are often used together to create powerful and efficient data processing and search solutions. They serve different purposes, and their integration can provide a robust system for data storage, retrieval, and search.
#
# For example, Redis can be used as a caching layer in front of Elasticsearch. This helps reduce the load on Elasticsearch by storing frequently accessed data in Redis. When a request is made, the system checks Redis first. If the data is found, it's served directly from Redis, reducing the response time. If the data is not in Redis, the system retrieves it from Elasticsearch, stores it in Redis, and serves it to the user. This approach improves response times and reduces the load on Elasticsearch.

# %% [markdown]
# In many applications, you can combine Elasticsearch for search and analytics with Redis for caching and real-time data needs. For example, you can use Elasticsearch for primary data storage and retrieval, while Redis caches frequently accessed data to reduce the load on Elasticsearch and improve response times.

# %% [markdown]
# ## Installation

# %% [markdown]
# ### Docker

# %% [markdown]
# #### Installing Docker

# %% [markdown]
# To play with redis we will need to have Docker installed. A tutorial on how to install Docker can be found [here](https://www.di.ubi.pt/~rcampos/DataScience/1Toolkit/2Docker).

# %% [markdown]
# #### redis

# %% [markdown]
# Once we have Docker installed, we will be ready to proceed with the redis installation making use of the `docker-compose.yml` file, which should be saved in a folder of your choice (e.g., `H:\Backup\Research\Programming\CodePython\MyDocker\redis`).

# %% [markdown]
# ```python
# version: '3.7'
# services:
#
#   redis:
#     image: redis/redis-stack:latest
#     ports:
#       - 6379:6379
#       - 8001:8001
#     environment:
#       - REDISEARCH_ARGS=CONCURRENT_WRITE_MODE
#     volumes:
#       - vector-db:/data
#     healthcheck:
#       test: ["CMD", "redis-cli", "-h", "localhost", "-p", "6379", "ping"]
#       interval: 2s
#       timeout: 1m30s
#       retries: 5
#       start_period: 5s
#
# volumes:
#   vector-db:
#       driver: local
#       driver_opts:
#         type: 'none'
#         o: 'bind'
#         device: 'h:\Backup\Research\Programming\CodePython\MyDocker\redis\data'
# ```

# %% [markdown]
# The code defines a service named redis that runs a Redis database, specifically using the `redis-stack` image. Let's break down the key components of this configuration:
#
# - `redis`: This is the name of the docker service being defined.
# - `image`: It specifies the Docker image to use for this service, in this case, "redis/redis-stack:latest." It will pull the latest version of the Redis image from Docker Hub.
# - `container_name: redis`: This line gives the container the name "redis." You can reference this name when interacting with the container or other Docker commands.
# - `ports`: This section maps ports on the host to ports within the container. It specifies that port 6379 on the host should be mapped to port 6379 in the container, and port 8001 on the host should be mapped to port 8001 in the container. This allows external applications to connect to Redis on port 6379 and access the redis-insight on port 8001 inside the container.
# - `environment`: This sets environment variables for the container. It specifies REDISEARCH_ARGS with the value CONCURRENT_WRITE_MODE.
# - `volumes`: it defines a named volume named "redis_data" and binds it to the /data directory within the container. This setup is used to persist Redis data so that it survives container restarts or removals. The data will be stored in the "redis_data" volume on the host machine (more on this below).
# - `healthcheck`: This section specifies a health check for the service to ensure it's running correctly. It uses the redis-cli command to ping the Redis server running on "localhost" at port 6379. If the command succeeds, the service is considered healthy. The health check runs every 2 seconds, with a timeout of 1 minute and 30 seconds. It retries up to 5 times, and it starts checking health after a delay of 5 seconds.
# - `Volume Configuration`: This section defines the "redis_data" volume. It specifies that the volume should be of type "local" and binds the volume to a host directory (device) located at the specified path on your local machine. This is where Redis data will be stored outside the container.

# %% [markdown]
# On the prompt, move to the folder where you have your `docker-compose.yml` file.

# %% [markdown]
# ```python
# h:
# cd h:\Backup\Research\Programming\CodePython\MyDocker\redis
# ```

# %% [markdown]
# Next execute the following command:

# %% [markdown]
# `docker-compose up -d`, where `-d` (from detach) means that the process will be running in background.

# %% [markdown]
# This will start pulling the images from docker registry and create the containers. It may take a while depending on whether you already have the images on your machine or not and also depending on your internet speed.

# %% [markdown]
# At the end, try to access **redis-insight** (redis UI):

# %% [markdown]
# http://localhost:8001

# %% [markdown]
# <hr>

# %% [markdown]
# ## Play with Redis on Python

# %% [markdown]
# To connect and use Redis in python, we will be using a python module **called redis-py**. It can be installed by running the following command in the command prompt.

# %%
# !pip install redis

# %% [markdown]
# ### Hello World Example

# %% [markdown]
# #### Connect to Redis

# %% [markdown]
# Now that we have everything ready, let’s get our hands dirty and dive into the programming part. `db=0` means that we are connecting to database 0.

# %%
import redis

# connect to redis
r = redis.Redis(host='localhost', port=6379, db=0)

# %% [markdown]
# #### Indexing

# %% [markdown]
# Now that we have connected to the Redis server, let’s start performing simple operations.
# To set a key-value pair, we use the `set` function that accepts the key and the value as the parameter. Please note that the key should always be either of string data type or bytes.

# %%
# set a key
r.set('test-key', 'test-value')
# Out:
# True

# %% [markdown]
# You can check the results on redis-insight: http://localhost:8001

# %% [markdown]
# #### Get

# %% [markdown]
# To get the value for a specific key, we use the `get` function that accepts the key for which we want the value to be returned.

# %%
# get a value
value = r.get('test-key')
print(value)
# Out:
# b'test-value'

# %% [markdown]
# Notice also that the type of the returned object, `b'` is Python’s bytes type, not str. It is bytes rather than str that is the most common return type across redis-py, so you may need to call `r.get("test-key").decode("utf-8")` depending on what you want to actually do with the returned bytestring.

# %%
# get a value
value = r.get('test-key').decode("utf-8")
print(value)
# Out:
# test-value

# %% [markdown]
# #### Exists

# %% [markdown]
# The `exists` command check if a key exists:

# %%
r.exists('test-key')
# Out:
# 1

# %% [markdown]
# #### Delete key-value pair

# %% [markdown]
# To delete some key just use the following code:

# %% [markdown]
# ```python
# r.delete('test-key')
# ```

# %% [markdown]
# #### Delete database

# %% [markdown]
# In Redis, you can't delete an entire database as you can with some other databases. Redis doesn't provide a command to remove all keys and data from a specific database, but you can delete keys individually or flush the entire dataset as follows:

# %% [markdown]
# ```python
# r.flushdb()
# ```

# %% [markdown]
# You may also use the following code to flush all databases:

# %% [markdown]
# ```python
# r.flushall()
# ```

# %% [markdown]
# #### Persistently Storage

# %% [markdown]
# Since Redis stores data in-memory, it does not face the same read/write (I/O) limitations and performance issues that databases face with hard disks. Although Redis stores and accesses data in-memory, it can be persisted on the hard disk for resilience; Docker Volumes makes this process easy. In our case data will be stored within the folder defined in the docker-compose.yml file, which was `H:\Backup\Research\Programming\CodePython\MyDocker\redis\data`

# %% [markdown]
# To save data persistently one has two options:
# 1. Under redis insight (http://localhost:8001) one can go to the `cli` option (on the bottom of the page) and write the following command: `save`
# 2. Alternatively, on the CMD one can write the following command `docker exec -ti redis /bin/bash`, where `redis` is the container name to access the redis file structure. Once inside, move to the `data` folder and execute the following command: `redis-cli save`.

# %% [markdown]
# Regardless the option used, a file named `dump.rdb` will be saved under our local folder `H:\Backup\Research\Programming\CodePython\MyDocker\redis\data`. This means that if your data gets corrupted or you run into problems with your docker container, you will always have your data here (don't forget to save it from time to time). If you want to try this, just remove the docker container (on docker desktop, for example) and run again the docker-compose command. Then go the redis-insight and you will see that your data is there.

# %% [markdown]
# ### Index Different Types of Data

# %% [markdown]
# Redis also allows you to set and get multiple key-value pairs in one command, `MSET` and `MGET`.

# %% [markdown]
# This new information, however, will be saved in another database. To do so, we should connect again to redis, but this time specifying `db=1`.

# %%
import redis

# connect to redis
r = redis.Redis(host='localhost', port=6379, db=1)

# %% [markdown]
# Next, we are going to `set` the multiple key-value pairs.

# %%
r.mset({"Croatia": "Zagreb", "Bahamas": "Nassau"})
# Out:
# True

# %% [markdown]
# And `get` them as follows:

# %%
ListOfValues = r.mget('Croatia','Bahamas')
ListOfValues
# Out:
# [b'Zagreb', b'Nassau']

# %% [markdown]
# In case you want to see this key-value pairs in the redis-insight UI just change on the top of the interface from db0 to db1.

# %% [markdown]
# If you want to store deeply nested objects with different data types, serialization techniques like using json or pickle can be used. Let’s see this in action to better understand. The following code stores information about a given employee.

# %%
import json
e1={
    "first_name":"nitin",
    "last_name":"panwar",
    "age": 27,
    "about": "Love to play cricket",
    "interests": ['sports','music'],
}
r.set('e1', json.dumps(e1))
# Out:
# True

# %% [markdown]
# To extract the information stored, we can directly use “get” function and then undo the stringification performed by json.

# %%
json.loads(r.get('e1'))
# Out:
# {'first_name': 'nitin',
#  'last_name': 'panwar',
#  'age': 27,
#  'about': 'Love to play cricket',
#  'interests': ['sports', 'music']}

# %% [markdown]
# Now lets insert some more employees:

# %%
# Let's insert some more documents
e2={
    "first_name" :  "Jane",
    "last_name" :   "Smith",
    "age" :         32,
    "about" :       "I like to collect rock albums",
    "interests":  [ "music" ]
}
e3={
    "first_name" :  "Douglas",
    "last_name" :   "Fir",
    "age" :         35,
    "about":        "I like to build cabinets",
    "interests":  [ "forestry" ]
}
e4={
    "first_name":"asd",
    "last_name":"pafdfd",
    "age": 27,
    "about": "Love to play football",
    "interests": ['sports','music'],
}

r.set('e2', json.dumps(e2))
r.set('e3', json.dumps(e3))
r.set('e4', json.dumps(e4))
# Out:
# True

# %% [markdown]
# Now suppose a situation, where, instead of having multiple dictionaries (one for each employee) we have a list of employees, where each position is a dictionary keeping the info of one given employee:

# %%
import json
import redis

# connect to redis
r = redis.Redis(host='localhost', port=6379, db=0)

# Employee information
e1={
    "first_name":"nitin",
    "last_name":"panwar",
    "age": 27,
    "about": "Love to play cricket",
    "interests": ['sports','music'],
}

e2={
    "first_name" :  "Jane",
    "last_name" :   "Smith",
    "age" :         32,
    "about" :       "I like to collect rock albums",
    "interests":  [ "music" ]
}

ListOfEmployees = [e1, e2]

r.set('ListOfEmployees', json.dumps(ListOfEmployees))
# Out:
# True

# %% [markdown]
# To get the list of employees we can simply run the following code:

# %%
json.loads(r.get('ListOfEmployees'))

# %% [markdown]
# Now suppose that you want to add a new employee to the list. How to do that?
# 1. Retrieve the existing ListOfEmployees from Redis.
# 2. Deserialize the JSON data to get a Python list.
# 3. Append the new employee (e3) to the list.
# 4. Serialize the updated list back to JSON and Store the updated JSON data in Redis.

# %%
import json
import redis

# Connect to Redis
r = redis.Redis(host='localhost', port=6379, db=1)

# Retrieve the existing ListOfEmployees from Redis
existing_data = r.get('ListOfEmployees')

# Check if any data exists in Redis
if existing_data:
    # Deserialize the existing JSON data to a Python list
    existing_employees = json.loads(existing_data)
else:
    # If no data exists, create an empty list
    existing_employees = []

# Define the new employee (e3)
e3 = {
    "first_name": "John",
    "last_name": "Doe",
    "age": 35,
    "about": "I enjoy hiking and photography",
    "interests": ["outdoor activities", "photography"],
}

# Append the new employee (e3) to the existing list
existing_employees.append(e3)

# Serialize the updated list back to JSON and Store the updated JSON data in Redis
r.set('ListOfEmployees', json.dumps(existing_employees))
# Out:
# True

# %% [markdown]
# ### Redisearch

# %% [markdown]
# [RediSearch](https://nimblehq.co/blog/getting-started-with-redisearch) is a Full-Text Search engine, available as a module for Redis. In a full-text search, a search engine examines all of the words in every stored document as it tries to match search criteria e.g. the text specified by a user. Contrary to wildcard search offered by databases via LIKE query, full-text search is primarily based on natural language processing

# %% [markdown]
# Let's start by flushing the database before proceeding.

# %%
r.flushdb()
# Out:
# True

# %% [markdown]
# #### Traditional Search

# %% [markdown]
# ##### Indexing

# %% [markdown]
# The first thing to do is to connect to redis. Note that we are not specifying any database in particular, thus it will store the results in `db0`.

# %%
import redis

def connect_redis():    
    r = redis.Redis(
            host="localhost",
            port=6379,
            decode_responses=True,
        )

    return r

# %% [markdown]
# The below cells will show how to specify and create a search index in Redis

# %%
from redis.commands.search.indexDefinition import IndexDefinition

def create_index(r, index_name, doc_prefix, fields):    
    try:
        #  check if index exists
        r.ft(index_name).info()
        print("Index already exists!")
    except:
        #create index
        r.ft(index_name).create_index(fields=fields, definition=IndexDefinition(prefix=[doc_prefix]))
        print("Index created")

# %% [markdown]
# Now that we have a search index, we can load documents into it.

# %%
def index_documents(r, doc_prefix, documents):
    for i, doc in enumerate(documents):
        key = f"{doc_prefix}{str(i)}"
        r.hset(key, mapping=doc)
    
    print("Documents indexed")

# %% [markdown]
# We may also want to delete all the data and the index using the following code.

# %%
def drop_data(r, index_name, delete_documents=True):
    try:
        r.ft(index_name).dropindex(delete_documents=delete_documents)
        print('Index and data dropped')
    except:
        print('Index does not exist')

# %% [markdown]
# The following gathers all the code together. We begin by defining the data to index (the employee information). Note that RediSearch primarily indexes and searches textual data. If `interests` is a list of strings representing the interests of employees, you should ensure that the data you store in the "interests" field is serialized as text (e.g., as JSON) so that it can be indexed and searched as a text field within RediSearch.

# %% [markdown]
# Next, we define some variables such as the `index_name` (the name of the index) and `doc_prefix` (the prefix for the document keys). In addition to that, `first_name`, `last_name`, `about` and `interests` are defined as a `TextField`, while `age` as a `NumericField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import json
import redis
from redis.commands.search.field import TextField, NumericField

# Employee information
e1={
    "first_name":"nitin",
    "last_name":"panwar",
    "age": 27,
    "about": "Love to play cricket",
    "interests": json.dumps(['sports', 'music'])
}

e2={
    "first_name" :  "Jane",
    "last_name" :   "Smith",
    "age" :         32,
    "about" :       "I like to collect rock albums",
    "interests":  json.dumps(['music'])
}

e3={
    "first_name" :  "Douglas",
    "last_name" :   "Fir",
    "age" :         35,
    "about":        "I like to build cabinets",
    "interests":  json.dumps(["forestry" ])
}
e4={
    "first_name":"asd",
    "last_name":"pafdfd",
    "age": 27,
    "about": "Love to play football",
    "interests": json.dumps(['sports','music'])
}

ListOfEmployees = [e1, e2, e3, e4]

#Define variables
index_name = 'idx:employees' #the name of the index, which you will use when doing queries
doc_prefix = 'employees:' #prefix for the document keys

# Define RediSearch fields
first_name = TextField(name="first_name")
last_name = TextField(name="last_name")
age = NumericField(name="age")
about = TextField(name="about")
interests = TextField(name="interests")

fields = [first_name, last_name, age, about, interests]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, ListOfEmployees)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# You can check the results on redis-insight: http://localhost:8001. To do so, go to the top-left corner of redis interface and click the button `search by values or keys`, specifying the `idx:employees`

# %% [markdown]
# As all of the above functions will be used once and then from now onwards. To make things easier, we should create (in the same folder of this notebook) a file named `redis_service.py` with the code and the imports of each of the four functions: `connect_redis`, `create_index`, `index_documents` and `drop_data`.

# %% [markdown]
# ##### Searching

# %% [markdown]
# The following illustrates the wildcard used to get all the results in the index:

# %%
results = r.ft(index_name).search("@*")
results
# Out:
# Result{4 total, docs: [Document {'id': 'employees:1', 'payload': None, 'first_name': 'Jane', 'last_name': 'Smith', 'age': '32', 'about': 'I like to collect rock albums', 'interests': '["music"]'}, Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}, Document {'id': 'employees:3', 'payload': None, 'first_name': 'asd', 'last_name': 'pafdfd', 'age': '27', 'about': 'Love to play football', 'interests': '["sports", "music"]'}, Document {'id': 'employees:2', 'payload': None, 'first_name': 'Douglas', 'last_name': 'Fir', 'age': '35', 'about': 'I like to build cabinets', 'interests': '["forestry"]'}]}

# %% [markdown]
# To get the total number of docs execute the following code:

# %%
results.total
# Out:
# 4

# %% [markdown]
# And to iterate over the results the following:

# %%
for doc in results.docs:   
    print(doc.id)
    print(doc.first_name)
    print(doc.last_name)
    print(doc.age)
    print(doc.about)
    print(json.loads(doc.interests))
    print("\n")
# Out:
# employees:1
# Jane
# Smith
# 32
# I like to collect rock albums
# ['music']
#
#
# employees:0
# nitin
# panwar
# 27
# Love to play cricket
# ['sports', 'music']
#
#
# employees:3
# asd
# pafdfd
# 27
# Love to play football
# ['sports', 'music']
#
#
# employees:2
# Douglas
# Fir
# 35
# I like to build cabinets
# ['forestry']

# %% [markdown]
# To search for results among all the fields you just need to specify the query (e.g., `nitin`).

# %%
results = r.ft(index_name).search('nitin')
results
# Out:
# Result{1 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# If you want to search for a specific field you can use the `@name_of_field` (e.g., `@first_name`). You may also want to use *abc* to look for a text that has `abc` inside. The following retrieves the documents where the field `first_name` has the word `nitin`.

# %%
#  search a specific field
results = r.ft(index_name).search('@first_name:*nitin*')
results
# Out:
# Result{1 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# In case you are looking for an exact match you cannot use the `*`:

# %%
#  search a specific field
results = r.ft(index_name).search('@about:play cricket')
results
# Out:
# Result{1 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# And if you want to retrieve all those documents that either have `play` or `cricket` then you can use the or (`|`) operator. Looking at the second result you can observe that it only has the word `play` in the text: `Love to play football`.

# %%
results = r.ft(index_name).search("@about:play|@about:cricket")
results
# Out:
# Result{2 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}, Document {'id': 'employees:3', 'payload': None, 'first_name': 'asd', 'last_name': 'pafdfd', 'age': '27', 'about': 'Love to play football', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# You may use the operator or (`|`) to specify a query in different fields. In the following we are looking for the word `nitin` within the fields `first_name` and `about`:

# %%
#  search specific fields - OR operation
results = r.ft(index_name).search('@first_name|about:nitin')
results
# Out:
# Result{1 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# Or specify an `and` condition, that is, an exact match

# %%
#  search specific fields - AND operation
results = r.ft(index_name).search('@first_name:nitin @about:nitin')
results
# Out:
# Result{0 total, docs: []}

# %% [markdown]
# We can also search for results in a list:

# %%
#  search a specific field
results = r.ft(index_name).search('@interests:music')
results
# Out:
# Result{3 total, docs: [Document {'id': 'employees:1', 'payload': None, 'first_name': 'Jane', 'last_name': 'Smith', 'age': '32', 'about': 'I like to collect rock albums', 'interests': '["music"]'}, Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}, Document {'id': 'employees:3', 'payload': None, 'first_name': 'asd', 'last_name': 'pafdfd', 'age': '27', 'about': 'Love to play football', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# One of the coolest features is `fuzzy search` which allows aproximate searches. This is good in cases when input query or documents can contain errors. In order to fuzzy match, we need to wrap our phrase with `%`:

# %%
# fuzzy search
results = r.ft(index_name).search('@about:%criket%')
results
# Out:
# Result{1 total, docs: [Document {'id': 'employees:0', 'payload': None, 'first_name': 'nitin', 'last_name': 'panwar', 'age': '27', 'about': 'Love to play cricket', 'interests': '["sports", "music"]'}]}

# %% [markdown]
# Next delete all data and the index:

# %%
r = connect_redis()
index_name = 'idx:employees'
drop_data(r, index_name)
# Out:
# Index and data dropped

# %% [markdown]
# ##### Quizzes

# %% [markdown]
# ###### Big Bang Theory

# %% [markdown]
# In this exercise we want to index information related to the `Big Bang Theory` show, namely:
# - id
# - season
# - episode
# - name
# - summary

# %% [markdown]
# To this regard, we are going to use the [Tvmaze](https://www.tvmaze.com/api) API through the following endpoint: `http://api.tvmaze.com/singlesearch/shows?q=big-bang-theory&embed=episodes`.

# %%
import requests
r = requests.get('http://api.tvmaze.com/singlesearch/shows?q=big+bang+theory&embed=episodes')

# %% [markdown]
# To see the total number of episodes:

# %%
contentsJSon = r.json()
len(contentsJSon["_embedded"]["episodes"])
# Out:
# 279

# %% [markdown]
# To get information from the first episode:

# %%
contentsJSon = r.json()
contentsJSon["_embedded"]["episodes"][0]
# Out:
# {'id': 2913,
#  'url': 'https://www.tvmaze.com/episodes/2913/the-big-bang-theory-1x01-pilot',
#  'name': 'Pilot',
#  'season': 1,
#  'number': 1,
#  'type': 'regular',
#  'airdate': '2007-09-24',
#  'airtime': '20:30',
#  'airstamp': '2007-09-25T00:30:00+00:00',
#  'runtime': 30,
#  'rating': {'average': 7.7},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/4/12368.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/4/12368.jpg'},
#  'summary': '<p>Is a comedy about brilliant physicists, Leonard and Sheldon, who are the kind of "beautiful minds" that understand how the universe works. But none of that genius helps them interact with people, especially women. All this begins to change when a free-spirited beauty named Penny moves in next door. Sheldon, Leonard\'s roommate, is quite content spending his nights playing Klingon Boggle with their socially dysfunctional friends, fellow Cal Tech scientists Wolowitz and Koothrappali. However, Leonard sees in Penny a whole new universe of possibilities... including love.</p>',
#  '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/2913'},
#   'show': {'href': 'https://api.tvmaze.com/shows/66',
#    'name': 'The Big Bang Theory'}}}

# %% [markdown]
# Execute the following code to create a list of dicts, where each object represents a doc to index. Note that the `summary` field includes some boilerplate which is to be removed by the `re` library.

# %%
import re
ldocs = []
for jo in contentsJSon["_embedded"]["episodes"][0:200]:
    d = {}
    d['id'] = jo['id']
    d['season'] = jo['season']
    d['episode'] = jo['number']
    d['name'] = jo['name']
    d["summary"] = re.sub('<[^<]+?>', '', jo['summary'])
    ldocs.append(d)

# %% [markdown]
# `ldocs` contains 200 docs to be indexed.

# %%
ldocs
# Out:
# [{'id': 2913,
#   'season': 1,
#   'episode': 1,
#   'name': 'Pilot',
#   'summary': 'Is a comedy about brilliant physicists, Leonard and Sheldon, who are the kind of "beautiful minds" that understand how the universe works. But none of that genius helps them interact with people, especially women. All this begins to change when a free-spirited beauty named Penny moves in next door. Sheldon, Leonard\'s roommate, is quite content spending his nights playing Klingon Boggle with their socially dysfunctional friends, fellow Cal Tech scientists Wolowitz and Koothrappali. However, Leonard sees in Penny a whole new universe of possibilities... including love.'},
#  {'id': 2914,
#   'season': 1,
#   'episode': 2,
#   'name': 'The Big Bran Hypothesis',
#   'summary': 'Leonard volunteers to sign for a package, hoping to make a good impression on Penny. When he enlists the help of his obsessive-compulsive roommate, Sheldon, his attempt at chivalry goes horribly awry.'},
#  {'id': 2915,
#   'season': 1,
#   'episode': 3,
#   'name': 'The Fuzzy Boots Corollary',
#   'summary': 'Leonard is bummed to learn that his crush, Penny, is seeing someone, so encouraged by his friends and fellow scientists, Leonard actually summons the nerve to ask a woman out on a date.'},
#  {'id': 2916,
#   'season': 1,
#   'episode': 4,
#   'name': 'The Luminous Fish Effect',
#   'summary': "When Sheldon gets fired, he explores life beyond physics, but his initial thrill of shopping with Penny devolves over time to him weaving ponchos as a shut-in, forcing Leonard to call on Sheldon's mother."},
#  {'id': 2917,
#   'season': 1,
#   'episode': 5,
#   'name': 'The Hamburger Postulate',
#   'summary': "After sensing his pursuit of Penny isn't going anywhere, Leonard agrees to an unexpected sexual encounter with fellow scientist Leslie Winkle."},
#  {'id': 2918,
#   'season': 1,
#   'episode': 6,
#   'name': 'The Middle-Earth Paradigm',
#   'summary': 'Leonard, Sheldon, Wolowitz and Koothrappali undertake a challenging and risky experiment-attending the Halloween party being thrown by their hot neighbor, Penny.'},
#  {'id': 2919,
#   'season': 1,
#   'episode': 7,
#   'name': 'The Dumpling Paradox',
#   'summary': "When Wolowitz seduces Penny's friend and takes over her apartment, Penny sleeps on Leonard and Sheldon's couch. With Wolowitz preoccupied, the guys discover they are without a fourth member of their group and in desperation, they ask Penny to join their Halo team."},
#  {'id': 2920,
#   'season': 1,
#   'episode': 8,
#   'name': 'The Grasshopper Experiment',
#   'summary': 'Koothrappali is overwhelmed after his parents arrange a blind date, but he discovers he actually can talk to the opposite sex after a few drinks; however, complications set in when his beautiful date is more interested in Sheldon.'},
#  {'id': 2921,
#   'season': 1,
#   'episode': 9,
#   'name': 'The Cooper-Hofstadter Polarization',
#   'summary': 'When Sheldon and Leonard are invited to present their joint findings at a physics conference, Sheldon refuses, and Penny steps in to mediate, only deepening the rift between the two best friends.'},
#  {'id': 2922,
#   'season': 1,
#   'episode': 10,
#   'name': 'The Loobenfeld Decay',
#   'summary': 'After hearing Penny sing, Leonard lies to avoid seeing her perform, but Sheldon takes it one step further with a more elaborate lie that leads to the appearance of his non-existent cousin.'},
#  {'id': 2923,
#   'season': 1,
#   'episode': 11,
#   'name': 'The Pancake Batter Anomaly',
#   'summary': "When Sheldon gets sick, Leonard and the boys know what's in store and avoid him like the plague, leaving an unsuspecting Penny to nurse the world's worst patient back to health."},
#  {'id': 2924,
#   'season': 1,
#   'episode': 12,
#   'name': 'The Jerusalem Duality',
#   'summary': "When Leonard and Sheldon meet a 15-year-old physics prodigy, Sheldon is distraught that this boy genius is younger and smarter, so in an attempt to restore his sense of purpose, the boys come up with a solution to derail Dennis' research."},
#  {'id': 2925,
#   'season': 1,
#   'episode': 13,
#   'name': 'The Bat Jar Conjecture',
#   'summary': "Since Sheldon's only focus is to prove his mental superiority while preparing for the Physics Bowl, the guys kick him off the team and enlist his nemesis Leslie Winkle."},
#  {'id': 2926,
#   'season': 1,
#   'episode': 14,
#   'name': 'The Nerdvana Annihilation',
#   'summary': 'When Leonard and the guys buy a time machine prop from a classic 1960 movie, its arrival creates problems for Penny and she tells the boys that their obsession with comics and toys is "pathetic".'},
#  {'id': 2927,
#   'season': 1,
#   'episode': 15,
#   'name': 'The Pork Chop Indeterminacy',
#   'summary': "When Leonard, Wolowitz, and Koothrappali all become smitten with Sheldon's twin sister, Leonard devises a plan to eliminate his rivals, however, it backfires when Sheldon declares he will decide whom his sister dates."},
#  {'id': 2928,
#   'season': 1,
#   'episode': 16,
#   'name': 'The Peanut Reaction',
#   'summary': "When Penny learns that Leonard doesn't celebrate birthdays, she attempts to throw him a surprise party, but is sidetracked by Sheldon who unexpectedly gets to live out one of his greatest fantasies at an electronics store."},
#  {'id': 2929,
#   'season': 1,
#   'episode': 17,
#   'name': 'The Tangerine Factor',
#   'summary': 'When Leonard asks Penny out on a date and she says yes, they each seek the "wisdom" of reluctant advisor.'},
#  {'id': 2930,
#   'season': 2,
#   'episode': 1,
#   'name': 'The Bad Fish Paradigm',
#   'summary': "After her first date with Leonard goes awry, Penny finds an unwilling confidant in Leonard's anti-social roommate, Sheldon."},
#  {'id': 2931,
#   'season': 2,
#   'episode': 2,
#   'name': 'The Codpiece Topology',
#   'summary': "When Leonard sees Penny with a handsome new guy, he enters into a rebound relationship with Sheldon's nemesis, Leslie Winkle."},
#  {'id': 2932,
#   'season': 2,
#   'episode': 3,
#   'name': 'The Barbarian Sublimation',
#   'summary': 'Sheldon creates a monster when he introduces Penny to the world of online gaming.'},
#  {'id': 2933,
#   'season': 2,
#   'episode': 4,
#   'name': 'The Griffin Equivalency',
#   'summary': "Raj, newly famous because of an article in a magazine, gets a big head and makes a disastrous play for Leonard's crush, Penny."},
#  {'id': 2934,
#   'season': 2,
#   'episode': 5,
#   'name': 'The Euclid Alternative',
#   'summary': 'Leonard and his friends stage an intervention to make Sheldon confront his longstanding fear of driving.'},
#  {'id': 2935,
#   'season': 2,
#   'episode': 6,
#   'name': 'The Cooper-Nowitzki Theorem',
#   'summary': "Young grad student's attraction to Sheldon confuses everyone, including Sheldon himself."},
#  {'id': 2936,
#   'season': 2,
#   'episode': 7,
#   'name': 'The Panty Piñata Polarization',
#   'summary': 'Penny vows to get revenge on Sheldon when he bans her from the apartment for a series of petty infractions.'},
#  {'id': 2937,
#   'season': 2,
#   'episode': 8,
#   'name': 'The Lizard-Spock Expansion',
#   'summary': "Wolowitz thinks he's found the love of his life, until she meets Leonard."},
#  {'id': 2938,
#   'season': 2,
#   'episode': 9,
#   'name': 'The White Asparagus Triangulation',
#   'summary': "Sheldon can barely contain his joy when Leonard starts dating a woman who meets Sheldon's exacting standards."},
#  {'id': 2939,
#   'season': 2,
#   'episode': 10,
#   'name': 'The Vartabedian Conundrum',
#   'summary': "When Leonard's relationship with a new woman starts moving too fast, he goes to Penny for advice."},
#  {'id': 2940,
#   'season': 2,
#   'episode': 11,
#   'name': 'The Bath Item Gift Hypothesis',
#   'summary': "Christmas is a source of stress for Leonard - whose handsome colleague starts dating Penny - and his friends, who are being tormented by Sheldon's obsession with gift-giving etiquette."},
#  {'id': 2941,
#   'season': 2,
#   'episode': 12,
#   'name': 'The Killer Robot Instability',
#   'summary': "When Penny's comment about Wolowitz's love life sends him into a depressed stupor, his friends lose their most important team-mate in an upcoming fighting robot competition."},
#  {'id': 2942,
#   'season': 2,
#   'episode': 13,
#   'name': 'The Friendship Algorithm',
#   'summary': 'Socially awkward Sheldon develops a scientific procedure for making friends.'},
#  {'id': 2943,
#   'season': 2,
#   'episode': 14,
#   'name': 'The Financial Permeability',
#   'summary': 'Sheldon\'s "simple" solution to Penny\'s financial problem leads to a confrontation between Leonard and Penny\'s hulking ex-boyfriend, Kurt.'},
#  {'id': 2944,
#   'season': 2,
#   'episode': 15,
#   'name': 'The Maternal Capacitance',
#   'summary': 'Disastrous visit from Mrs. Hofstadter brings Leonard and Penny closer together.'},
#  {'id': 2945,
#   'season': 2,
#   'episode': 16,
#   'name': 'The Cushion Saturation',
#   'summary': 'Paintball game leads to a fight between Penny and Sheldon, and romance for Wolowitz and Leslie.'},
#  {'id': 2946,
#   'season': 2,
#   'episode': 17,
#   'name': 'The Terminator Decoupling',
#   'summary': 'Train trip to San Francisco takes a major detour when Leonard, Sheldon, Wolowitz and Raj discover that beautiful sci-fi actress Summer Glau is onboard.'},
#  {'id': 2947,
#   'season': 2,
#   'episode': 18,
#   'name': 'The Work Song Nanocluster',
#   'summary': "Penny's home hair products business becomes a complete nightmare when a caffeine-addled Sheldon takes over."},
#  {'id': 2948,
#   'season': 2,
#   'episode': 19,
#   'name': 'The Dead Hooker Juxtaposition',
#   'summary': 'Penny develops a rivalry with a sexy female neighbor who threatens to become "The New Penny" in the building.'},
#  {'id': 2949,
#   'season': 2,
#   'episode': 20,
#   'name': 'The Hofstadter Isotope',
#   'summary': 'While a fellow comic book-loving pal of the guys romances Penny, Leonard and Wolowitz venture out into the world of "Ladies\' Night" at a local bar.'},
#  {'id': 2950,
#   'season': 2,
#   'episode': 21,
#   'name': 'The Vegas Renormalization',
#   'summary': 'Leonard and Koothrappali take a heartbroken Wolowitz to Las Vegas, leaving Sheldon locked out of his apartment and forced to bunk with Penny.'},
#  {'id': 2951,
#   'season': 2,
#   'episode': 22,
#   'name': 'The Classified Materials Turbulence',
#   'summary': "Things begin to look up for Leonard when Penny makes a surprising revelation on her second date with Stuart. Meanwhile, Wolowitz enlists his friends' help when he discovers a critical design flaw in his project for NASA."},
#  {'id': 2952,
#   'season': 2,
#   'episode': 23,
#   'name': 'The Monopolar Expedition',
#   'summary': 'Penny is conflicted when Leonard and his friends decide to spend the summer working - at the North Pole.'},
#  {'id': 2953,
#   'season': 3,
#   'episode': 1,
#   'name': 'The Electric Can Opener Fluctuation',
#   'summary': "Sheldon flees back to Texas in disgrace when he learns the guys tampered with his arctic expedition data, forcing the guys to follow him and threatening Leonard's hopes for a romantic encounter with Penny."},
#  {'id': 2954,
#   'season': 3,
#   'episode': 2,
#   'name': 'The Jiminy Conjecture',
#   'summary': 'Leonard and Penny struggle to recover from an awkward first hookup while Sheldon and Howard stake their best comic books on a bet to determine the species of a cricket.'},
#  {'id': 2955,
#   'season': 3,
#   'episode': 3,
#   'name': 'The Gothowitz Deviation',
#   'summary': 'Howard and Raj visit a Goth nightclub to pick up women while Sheldon attempts to build a better Penny using chocolate-based behavior modification.'},
#  {'id': 2956,
#   'season': 3,
#   'episode': 4,
#   'name': 'The Pirate Solution',
#   'summary': 'Raj must find a new job or be sent back to India, but Sheldon has a solution, which leaves Leonard and Penny dealing with Howard as third wheel.'},
#  {'id': 2957,
#   'season': 3,
#   'episode': 5,
#   'name': 'The Creepy Candy Coating Corollary',
#   'summary': 'While Sheldon settles a score with his nemesis, Wil Wheaton, Wolowitz begs Leonard to get Penny to set him up with one of her friends.'},
#  {'id': 2958,
#   'season': 3,
#   'episode': 6,
#   'name': 'The Cornhusker Vortex',
#   'summary': "Sheldon teaches Leonard how to understand football while a kite-fighting incident threatens Howard and Raj's friendship."},
#  {'id': 2959,
#   'season': 3,
#   'episode': 7,
#   'name': 'The Guitarist Amplification',
#   'summary': 'An argument between Leonard and Penny proves "inconvenient" to Sheldon.'},
#  {'id': 2960,
#   'season': 3,
#   'episode': 8,
#   'name': 'The Adhesive Duck Deficiency',
#   'summary': 'With Leonard, Howard and Raj away camping in the desert, an injured Penny has only Sheldon to rely on.'},
#  {'id': 2961,
#   'season': 3,
#   'episode': 9,
#   'name': 'The Vengeance Formulation',
#   'summary': "After he's humiliated on National Public Radio, Sheldon vows to destroy Kripke, while Wolowitz tries not to destroy his new relationship with Bernadette."},
#  {'id': 2962,
#   'season': 3,
#   'episode': 10,
#   'name': 'The Gorilla Experiment',
#   'summary': "Sheldon attempts to help Penny understand Leonard's work, and Wolowitz becomes jealous when Leonard starts hanging out with his new girlfriend."},
#  {'id': 2963,
#   'season': 3,
#   'episode': 11,
#   'name': 'The Maternal Congruence',
#   'summary': "Visit from Leonard's mother delights Sheldon and horrifies Leonard."},
#  {'id': 2964,
#   'season': 3,
#   'episode': 12,
#   'name': 'The Psychic Vortex',
#   'summary': 'While Sheldon and Koothrappali attend a university mixer, Leonard is upset to discover that Penny believes in psychics.'},
#  {'id': 2965,
#   'season': 3,
#   'episode': 13,
#   'name': 'The Bozeman Reaction',
#   'summary': 'When their apartment is robbed, Leonard and Sheldon turn to their friends to create a state-of-the-art security system.'},
#  {'id': 2966,
#   'season': 3,
#   'episode': 14,
#   'name': 'The Einstein Approximation',
#   'summary': "Sheldon's search for the answer to a physics problem leads him to work at the Cheesecake Factory with Penny."},
#  {'id': 2967,
#   'season': 3,
#   'episode': 15,
#   'name': 'The Large Hadron Collision',
#   'summary': "Leonard can only bring one guest on a trip to see CERN's Large Hadron Collider in Switzerland on Valentine's Day."},
#  {'id': 2968,
#   'season': 3,
#   'episode': 16,
#   'name': 'The Excelsior Acquisition',
#   'summary': 'Sheldon winds up in traffic court when he gets a ticket because of Penny.'},
#  {'id': 2969,
#   'season': 3,
#   'episode': 17,
#   'name': 'The Precious Fragmentation',
#   'summary': 'When the guys find a ring from "The Lord of the Rings" at a garage sale, it threatens to tear them apart.'},
#  {'id': 2970,
#   'season': 3,
#   'episode': 18,
#   'name': 'The Pants Alternative',
#   'summary': "Sheldon's friends come to his aid when his fear of public speaking stands between him and a coveted award."},
#  {'id': 2971,
#   'season': 3,
#   'episode': 19,
#   'name': 'The Wheaton Recurrence',
#   'summary': 'Fight between Leonard and Penny threatens their relationship, while Sheldon battles Wil Wheaton in bowling.'},
#  {'id': 2972,
#   'season': 3,
#   'episode': 20,
#   'name': 'The Spaghetti Catalyst',
#   'summary': "When Leonard and Penny aren't speaking, Sheldon goes to extremes to keep them both happy."},
#  {'id': 2973,
#   'season': 3,
#   'episode': 21,
#   'name': 'The Plimpton Stimulation',
#   'summary': 'Leonard and Sheldon compete for the attention of a famous female physicist.'},
#  {'id': 2974,
#   'season': 3,
#   'episode': 22,
#   'name': 'The Staircase Implementation',
#   'summary': 'Leonard tells Penny about how he met Sheldon for the first time...and what happened to the elevator.'},
#  {'id': 2975,
#   'season': 3,
#   'episode': 23,
#   'name': 'The Lunar Excitation',
#   'summary': "While Penny worries that dating Leonard has ruined her for normal guys, Wolowitz and Koothrappali search for Sheldon's perfect match online."},
#  {'id': 2976,
#   'season': 4,
#   'episode': 1,
#   'name': 'The Robotic Manipulation',
#   'summary': "Penny finds herself along for the ride on Sheldon's first date ever; while Wolowitz finds a new use for a robotic arm."},
#  {'id': 2977,
#   'season': 4,
#   'episode': 2,
#   'name': 'The Cruciferous Vegetable Amplification',
#   'summary': "Sheldon realizes he won't live long enough to download his consciousness into a robot body, and attempts to extend his lifespan."},
#  {'id': 2978,
#   'season': 4,
#   'episode': 3,
#   'name': 'The Zazzy Substitution',
#   'summary': 'The guys are concerned as Sheldon searches for an alternative to human companionship.'},
#  {'id': 2979,
#   'season': 4,
#   'episode': 4,
#   'name': 'The Hot Troll Deviation',
#   'summary': "An embarrassing secret of Wolowitz's comes to light, while Sheldon and Raj have a small war at work."},
#  {'id': 2980,
#   'season': 4,
#   'episode': 5,
#   'name': 'The Desperation Emanation',
#   'summary': "Leonard realizes he's the only one without a girlfriend, while Sheldon wants to get rid of his."},
#  {'id': 2981,
#   'season': 4,
#   'episode': 6,
#   'name': 'The Irish Pub Formulation',
#   'summary': 'Leonard keeps an affair secret from Sheldon, Howard and Raj.'},
#  {'id': 2982,
#   'season': 4,
#   'episode': 7,
#   'name': 'The Apology Insufficiency',
#   'summary': "Sheldon's answers during an FBI interview put Wolowitz's security clearance in jeopardy."},
#  {'id': 2983,
#   'season': 4,
#   'episode': 8,
#   'name': 'The 21-Second Excitation',
#   'summary': 'While the guys camp in line for a screening, Penny and Bernadette invite Amy to her first slumber party.'},
#  {'id': 2984,
#   'season': 4,
#   'episode': 9,
#   'name': 'The Boyfriend Complexity',
#   'summary': 'Penny asks Leonard to lie to her father, while Howard, Raj and Bernadette pull an all-nighter at a telescope.'},
#  {'id': 2985,
#   'season': 4,
#   'episode': 10,
#   'name': 'The Alien Parasite Hypothesis',
#   'summary': "Amy finds she has sexual feelings for Penny's ex, while Koothrappali and Wolowitz try to prove who would be the better superhero."},
#  {'id': 2986,
#   'season': 4,
#   'episode': 11,
#   'name': 'The Justice League Recombination',
#   'summary': 'The guys find a "super" use for Penny\'s new boyfriend, Zack, when they enter a costume contest as the Justice League.'},
#  {'id': 2987,
#   'season': 4,
#   'episode': 12,
#   'name': 'The Bus Pants Utilization',
#   'summary': "Leonard's idea for a smartphone app derails his friendship with Sheldon."},
#  {'id': 2988,
#   'season': 4,
#   'episode': 13,
#   'name': 'The Love Car Displacement',
#   'summary': 'Tension runs high when everyone is staying at the same hotel for a science event and Bernadette runs into her ex-boyfriend.'},
#  {'id': 2989,
#   'season': 4,
#   'episode': 14,
#   'name': 'The Thespian Catalyst',
#   'summary': "Sheldon hopes acting lessons from Penny will help him become a better teacher. Meanwhile, Koothrappali fantasizes about his best friend's girlfriend."},
#  {'id': 2990,
#   'season': 4,
#   'episode': 15,
#   'name': 'The Benefactor Factor',
#   'summary': "A wealthy donor to the university makes Leonard consider how far he's willing to go for the sake of science."},
#  {'id': 2991,
#   'season': 4,
#   'episode': 16,
#   'name': 'The Cohabitation Formulation',
#   'summary': "As Wolowitz contemplates taking things with Bernadette to the next level, Leonard rekindles his relationship with Raj's sister."},
#  {'id': 2992,
#   'season': 4,
#   'episode': 17,
#   'name': 'The Toast Derivation',
#   'summary': "Sheldon struggles to cope when he realizes it's actually Leonard who is the center of their social group."},
#  {'id': 2993,
#   'season': 4,
#   'episode': 18,
#   'name': 'The Prestidigitation Approximation',
#   'summary': 'Leonard must choose between new girlfriend Priya and his friendship with Penny. Meanwhile, Howard drives Sheldon crazy with a magic trick.'},
#  {'id': 2994,
#   'season': 4,
#   'episode': 19,
#   'name': 'The Zarnecki Incursion',
#   'summary': "When someone hacks Sheldon's online game account, the guys go on a quest to find the culprit."},
#  {'id': 2995,
#   'season': 4,
#   'episode': 20,
#   'name': 'The Herb Garden Germination',
#   'summary': 'Sheldon and Amy experiment on their friends by spreading gossip, while Howard takes a big step in his relationship with Bernadette.'},
#  {'id': 2996,
#   'season': 4,
#   'episode': 21,
#   'name': 'The Agreement Dissection',
#   'summary': 'When Priya uses her lawyer skills to pick apart the roommate agreement, the girls take Sheldon dancing.'},
#  {'id': 2997,
#   'season': 4,
#   'episode': 22,
#   'name': 'The Wildebeest Implementation',
#   'summary': 'Raj attempts to cure his social anxiety disorder while Penny uses Bernadette to spy on Leonard and his girlfriend.'},
#  {'id': 2998,
#   'season': 4,
#   'episode': 23,
#   'name': 'The Engagement Reaction',
#   'summary': "When Howard finally breaks the news to his mom that he's engaged to Bernadette, it lands her in the hospital."},
#  {'id': 2999,
#   'season': 4,
#   'episode': 24,
#   'name': 'The Roommate Transmogrification',
#   'summary': 'When Bernadette receives her Ph.D., the guys take joy in reminding an emasculated Wolowitz that he is the only one in their group who isn\'t a doctor. Meanwhile, Koothrappali becomes Sheldon\'s new roommate after hearing Leonard and Priya engaging in a "Star Trek" bedroom fantasy.'},
#  {'id': 3000,
#   'season': 5,
#   'episode': 1,
#   'name': 'The Skank Reflex Analysis',
#   'summary': "Penny worries that she's screwed things up permanently with her friends, while Sheldon takes command of the paintball team."},
#  {'id': 3001,
#   'season': 5,
#   'episode': 2,
#   'name': 'The Infestation Hypothesis',
#   'summary': 'Fight between Sheldon and Penny leaves Amy caught in the middle, while Leonard tries to spice up his long-distance relationship with Priya.'},
#  {'id': 3002,
#   'season': 5,
#   'episode': 3,
#   'name': 'The Pulled Groin Extrapolation',
#   'summary': 'Leonard and Amy get to know each other better, while Howard and Bernadette spend the weekend with Mrs. Wolowitz.'},
#  {'id': 3003,
#   'season': 5,
#   'episode': 4,
#   'name': 'The Wiggly Finger Catalyst',
#   'summary': 'Raj finally meets a girl he can communicate with.'},
#  {'id': 3004,
#   'season': 5,
#   'episode': 5,
#   'name': 'The Russian Rocket Reaction',
#   'summary': "Sheldon and Leonard get invited to a party at Wil Wheaton's house, and Howard gets an out-of-this-world opportunity."},
#  {'id': 3005,
#   'season': 5,
#   'episode': 6,
#   'name': 'The Rhinitis Revelation',
#   'summary': "Sheldon competes with the gang for his mother's attention when she comes to visit."},
#  {'id': 3006,
#   'season': 5,
#   'episode': 7,
#   'name': 'The Good Guy Fluctuation',
#   'summary': "Cute comic book artist puts Leonard and Priya's relationship to the test, while Sheldon tries to scare the guys for Halloween."},
#  {'id': 3007,
#   'season': 5,
#   'episode': 8,
#   'name': 'The Isolation Permutation',
#   'summary': 'Amy is crushed when Bernadette and Penny go shopping for wedding dresses without her.'},
#  {'id': 3008,
#   'season': 5,
#   'episode': 9,
#   'name': 'The Ornithophobia Diffusion',
#   'summary': 'Leonard and Penny try hanging out alone, and Sheldon must overcome his fear of birds.'},
#  {'id': 3009,
#   'season': 5,
#   'episode': 10,
#   'name': 'The Flaming Spittoon Acquisition',
#   'summary': 'Sheldon considers taking his relationship with Amy to the next level when Stuart from the comic book store asks her out on a date.'},
#  {'id': 3010,
#   'season': 5,
#   'episode': 11,
#   'name': 'The Speckerman Recurrence',
#   'summary': 'Leonard must face his fears after being contacted by his high school tormentor.'},
#  {'id': 3011,
#   'season': 5,
#   'episode': 12,
#   'name': 'The Shiny Trinket Maneuver',
#   'summary': "Sheldon gets in trouble with Amy when he isn't impressed by her recent accomplishment, and Howard must come to grips with Bernadette's dislike of children."},
#  {'id': 3012,
#   'season': 5,
#   'episode': 13,
#   'name': 'The Recombination Hypothesis',
#   'summary': 'Everything might change when Leonard offers Penny a spur of the moment invitation to a romantic dinner for two.'},
#  {'id': 3013,
#   'season': 5,
#   'episode': 14,
#   'name': 'The Beta Test Initiation',
#   'summary': "Leonard and Penny experiment with dating, while Raj develops a peculiar relationship with his phone's virtual assistant."},
#  {'id': 3014,
#   'season': 5,
#   'episode': 15,
#   'name': 'The Friendship Contraction',
#   'summary': "Sheldon's selfish demands force Leonard to reconsider their friendship. Meanwhile, Wolowitz tries to pick his astronaut nickname."},
#  {'id': 3015,
#   'season': 5,
#   'episode': 16,
#   'name': 'The Vacation Solution',
#   'summary': 'When Sheldon is forced to take his vacation, he goes to work with Amy in her neurobiology lab. Meanwhile, Bernadette wants Howard to sign a pre-nup.'},
#  {'id': 3016,
#   'season': 5,
#   'episode': 17,
#   'name': 'The Rothman Disintegration',
#   'summary': 'When an office at the University opens up, Sheldon must compete for it with his archenemy, Kripke. Meanwhile, a gift from Amy makes Penny uncomfortable.'},
#  {'id': 3017,
#   'season': 5,
#   'episode': 18,
#   'name': 'The Werewolf Transformation',
#   'summary': "Sheldon's life is turned upside-down after his barber gets sick. Meanwhile, astronaut training causes Wolowitz to rethink his decision to go into space."},
#  {'id': 3018,
#   'season': 5,
#   'episode': 19,
#   'name': 'The Weekend Vortex',
#   'summary': "Sheldon chooses to play video games with the guys rather than go with Amy to her aunt's birthday party."},
#  {'id': 3019,
#   'season': 5,
#   'episode': 20,
#   'name': 'The Transporter Malfunction',
#   'summary': 'Penny buys Leonard and Sheldon "Star Trek" collectibles as a thank-you, leading Sheldon to be haunted by Mr. Spock. Meanwhile, Raj decides he has met the "Future Mrs. Koothrappali" after his parents set him up on a date.'},
#  {'id': 3020,
#   'season': 5,
#   'episode': 21,
#   'name': 'The Hawking Excitation',
#   'summary': 'When Wolowitz gets to work with Stephen Hawking, Sheldon is willing to do anything to meet his hero.'},
#  {'id': 3021,
#   'season': 5,
#   'episode': 22,
#   'name': 'The Stag Convergence',
#   'summary': 'Bernadette reconsiders marrying Howard after learning about his sexual history.'},
#  {'id': 3022,
#   'season': 5,
#   'episode': 23,
#   'name': 'The Launch Acceleration',
#   'summary': "NASA reschedules Howard's mission, putting his and Bernadette's wedding plans in jeopardy. Meanwhile, Leonard says something surprising to Penny in the bedroom."},
#  {'id': 3023,
#   'season': 5,
#   'episode': 24,
#   'name': 'The Countdown Reflection',
#   'summary': 'When Howard and Bernadette decide they want to be married before his NASA launch, the gang rushes to put on a wedding.'},
#  {'id': 3024,
#   'season': 6,
#   'episode': 1,
#   'name': 'The Date Night Variable',
#   'summary': "With his friends on dates, Raj must face his loneliness. Also, Wolowitz is caught in an argument between Bernadette and his mom, even while he's in space."},
#  {'id': 3025,
#   'season': 6,
#   'episode': 2,
#   'name': 'The Decoupling Fluctuation',
#   'summary': 'When Sheldon learns that Penny is thinking about breaking up with Leonard, he tries to intervene. Meanwhile, in space, the other astronauts pick on Howard.'},
#  {'id': 3026,
#   'season': 6,
#   'episode': 3,
#   'name': 'The Higgs Boson Observation',
#   'summary': 'Amy feels threatened when Sheldon hires a young female assistant, and the pressure of being in space takes its toll on Wolowitz.'},
#  {'id': 3027,
#   'season': 6,
#   'episode': 4,
#   'name': 'The Re-Entry Minimization',
#   'summary': "When Wolowitz returns from space, he doesn't get the hero's welcome he expected. Meanwhile, Game Night turns into a battle of the sexes."},
#  {'id': 3028,
#   'season': 6,
#   'episode': 5,
#   'name': 'The Holographic Excitation',
#   'summary': "The gang celebrates Halloween at Stuart's comic book store. Meanwhile, Leonard seduces Penny with science."},
#  {'id': 3029,
#   'season': 6,
#   'episode': 6,
#   'name': 'The Extract Obliteration',
#   'summary': 'Sheldon\'s relationship with Stephen Hawking is threatened over a game of "Words with Friends," and Penny secretly enrolls in a class at the local college.'},
#  {'id': 3030,
#   'season': 6,
#   'episode': 7,
#   'name': 'The Habitation Configuration',
#   'summary': "Wolowitz struggles with moving out of his mother's house. Meanwhile, Sheldon is caught in the middle of an argument between Amy and Wil Wheaton."},
#  {'id': 3031,
#   'season': 6,
#   'episode': 8,
#   'name': 'The 43 Peculiarity',
#   'summary': 'Howard and Raj try to get to the bottom of why Sheldon disappears every afternoon at 2:45. Meanwhile, Leonard and Penny deal with jealousy in their relationship.'},
#  {'id': 3032,
#   'season': 6,
#   'episode': 9,
#   'name': 'The Parking Spot Escalation',
#   'summary': "When the University reassigns Sheldon's parking spot to Wolowitz, their fight affects the whole gang."},
#  {'id': 3033,
#   'season': 6,
#   'episode': 10,
#   'name': 'The Fish Guts Displacement',
#   'summary': 'Sheldon tries to nurse a sick Amy back to health, while Wolowitz prepares for an upcoming fishing trip with his father-in-law.'},
#  {'id': 3034,
#   'season': 6,
#   'episode': 11,
#   'name': 'The Santa Simulation',
#   'summary': "Sheldon revisits some Christmas memories during a game of Dungeons and Dragons, while Penny, Bernadette and Amy try to find a girl for Koothrappali when he joins the girls for ladies' night."},
#  {'id': 3035,
#   'season': 6,
#   'episode': 12,
#   'name': 'The Egg Salad Equivalency',
#   'summary': 'Sheldon gets accused of sexual harassment at the University and winds up getting Leonard, Raj and Wolowitz in trouble.'},
#  {'id': 3036,
#   'season': 6,
#   'episode': 13,
#   'name': 'The Bakersfield Expedition',
#   'summary': 'While the guys take a road trip to a comic book convention dressed as "Star Trek: The Next Generation" characters, the girls stay home and try to interpret a comic book.'},
#  {'id': 3037,
#   'season': 6,
#   'episode': 14,
#   'name': 'The Cooper/Kripke Inversion',
#   'summary': 'Sheldon is forced to work with Barry Kripke and faces a crisis of confidence. Meanwhile, Howard and Raj spend $1,000 on action figures of themselves.'},
#  {'id': 3038,
#   'season': 6,
#   'episode': 15,
#   'name': 'The Spoiler Alert Segmentation',
#   'summary': "When Sheldon and Leonard fight, it affects Penny and Amy's living arrangements. Meanwhile, Raj takes care of Mrs. Wolowitz while Howard is away."},
#  {'id': 3039,
#   'season': 6,
#   'episode': 16,
#   'name': 'The Tangible Affection Proof',
#   'summary': 'While the guys try to give their significant others the perfect Valentine\'s Day, Raj and Stuart throw a "lonely people" party at the comic book store.'},
#  {'id': 3040,
#   'season': 6,
#   'episode': 17,
#   'name': 'The Monster Isolation',
#   'summary': 'After a terrible date, Koothrappali vows to never leave his apartment. Meanwhile, Penny actually impresses Sheldon with her acting skills.'},
#  {'id': 3041,
#   'season': 6,
#   'episode': 18,
#   'name': 'The Contractual Obligation Implementation',
#   'summary': 'Leonard, Sheldon and Wolowitz speak to junior high girls about careers in science. Meanwhile, Koothrappali plans a date with Lucy.'},
#  {'id': 3042,
#   'season': 6,
#   'episode': 19,
#   'name': 'The Closet Reconfiguration',
#   'summary': 'Howard struggles with whether or not he should open a letter from his father, and Leonard and Penny throw a "grown-up" cocktail party at the apartment.'},
#  {'id': 3043,
#   'season': 6,
#   'episode': 20,
#   'name': 'The Tenure Turbulence',
#   'summary': 'Leonard, Sheldon and Raj fight for tenure at the University, and the competition heats up when the girls get involved.'},
#  {'id': 3044,
#   'season': 6,
#   'episode': 21,
#   'name': 'The Closure Alternative',
#   'summary': 'Sheldon feels lost after one of his favorite TV shows gets canceled too soon and Amy tries to help him get over his compulsive need for closure. Meanwhile, Raj discovers a secret about his new love interest, Lucy.'},
#  {'id': 3045,
#   'season': 6,
#   'episode': 22,
#   'name': 'The Proton Resurgence',
#   'summary': "Sheldon and Leonard hire Professor Proton, the host of their favorite childhood TV show, to perform. Also, Howard and Bernadette run into trouble babysitting Raj's dog."},
#  {'id': 3046,
#   'season': 6,
#   'episode': 23,
#   'name': 'The Love Spell Potential',
#   'summary': "When the girls' trip to Vegas falls through, the guys invite them to play Dungeons &amp; Dragons, causing Sheldon and Amy's relationship to take an unexpected turn. Meanwhile, Koothrappali and Lucy go on a very awkward date."},
#  {'id': 3047,
#   'season': 6,
#   'episode': 24,
#   'name': 'The Bon Voyage Reaction',
#   'summary': 'New success for Leonard makes Sheldon very jealous and throws Penny for a loop. Meanwhile, Koothrappali pushes Lucy too far in their relationship.'},
#  {'id': 3048,
#   'season': 7,
#   'episode': 1,
#   'name': 'The Hofstadter Insufficiency',
#   'summary': 'With Leonard away, Sheldon and Penny spend quality time together sharing intimate secrets. Also, Wolowitz helps Raj get over his ex-girlfriend.'},
#  {'id': 3049,
#   'season': 7,
#   'episode': 2,
#   'name': 'The Deception Verification',
#   'summary': "Leonard's friendship with Sheldon is put to the test when he returns from the North Sea. Meanwhile, Wolowitz's relationship with his mother causes an unusual threat to his masculinity."},
#  {'id': 3050,
#   'season': 7,
#   'episode': 3,
#   'name': 'The Scavenger Vortex',
#   'summary': 'When the entire gang competes in a scavenger hunt designed by Raj, it brings out the best - and worst - in everyone.'},
#  {'id': 3051,
#   'season': 7,
#   'episode': 4,
#   'name': 'The Raiders Minimization',
#   'summary': 'Sheldon seeks revenge after Amy ruins one of his favorite movies. Meanwhile, Leonard discovers a way to get Penny to do anything, and Raj and Stuart create online dating profiles.'},
#  {'id': 3052,
#   'season': 7,
#   'episode': 5,
#   'name': 'The Workplace Proximity',
#   'summary': 'Sheldon must decide how much "Amy time" is too much after she takes a job at his university. Meanwhile, Howard finds himself sleeping on Raj\'s couch after a fight with Bernadette.'},
#  {'id': 3053,
#   'season': 7,
#   'episode': 6,
#   'name': 'The Romance Resonance',
#   'summary': "Sheldon's major scientific breakthrough makes him feel like a fraud. Meanwhile, Howard's romantic gesture to Bernadette causes Penny to step up her game with Leonard."},
#  {'id': 3054,
#   'season': 7,
#   'episode': 7,
#   'name': 'The Proton Displacement',
#   'summary': 'Sheldon feels slighted when Professor Proton seeks advice from Leonard instead of him, and he seeks revenge by befriending a rival science TV host, Bill Nye. Meanwhile, Raj gets jealous when Howard crashes "girls\' night".'},
#  {'id': 3055,
#   'season': 7,
#   'episode': 8,
#   'name': 'The Itchy Brain Simulation',
#   'summary': "Leonard tries to keep Sheldon from overreacting when a past mistake comes to light, but Sheldon punishes Leonard by making him walk a mile in his shoes. Meanwhile, Penny confronts Raj's ex-girlfriend, Lucy."},
#  {'id': 3056,
#   'season': 7,
#   'episode': 9,
#   'name': 'The Thanksgiving Decoupling',
#   'summary': "Sheldon protests when the gang drags him to Mrs. Wolowitz's house for Thanksgiving. Meanwhile, Penny and Leonard must deal with a mistake from her past."},
#  {'id': 3057,
#   'season': 7,
#   'episode': 10,
#   'name': 'The Discovery Dissipation',
#   'summary': "Leonard and Amy help Sheldon cope with the shame he's feeling after his accidental contribution to science is disproved. Meanwhile, Raj must stay with Howard and Bernadette for a week."},
#  {'id': 3058,
#   'season': 7,
#   'episode': 11,
#   'name': 'The Cooper Extraction',
#   'summary': 'While Sheldon is away in Texas, everyone gathers to decorate the apartment Christmas tree, and they each realize how much he has changed their lives.'},
#  {'id': 3059,
#   'season': 7,
#   'episode': 12,
#   'name': 'The Hesitation Ramification',
#   'summary': 'When Penny\'s big acting break on NCIS is a bust, Leonard struggles to help her, which results in Penny asking Leonard a bold relationship question. Meanwhile, Sheldon tries to learn how to be funny and Raj tries to work on his "game" before talking to girls.'},
#  {'id': 3060,
#   'season': 7,
#   'episode': 13,
#   'name': 'The Occupation Recalibration',
#   'summary': "Sheldon tries to relax after he is forced to take a vacation. Meanwhile, Leonard struggles to be supportive of Penny after she quits her job, and Bernadette seeks Stuart's help in replacing one of Howard's comic books."},
#  {'id': 3061,
#   'season': 7,
#   'episode': 14,
#   'name': 'The Convention Conundrum',
#   'summary': 'After the guys can\'t get Comic-Con tickets, Sheldon tries to hold his own convention and winds up spending a wild night with James Earl Jones. Meanwhile, the girls see if they can act like "grown-ups".'},
#  {'id': 3062,
#   'season': 7,
#   'episode': 15,
#   'name': 'The Locomotive Manipulation',
#   'summary': "Love is in the air when Sheldon and Amy join Howard and Bernadette for a trip to wine country. Meanwhile, Leonard and Penny must rush Raj's dog to the vet."},
#  {'id': 3063,
#   'season': 7,
#   'episode': 16,
#   'name': 'The Table Polarization',
#   'summary': 'Leonard buys a dining room table and it causes Sheldon to reevaluate the changes in his life. Meanwhile, Wolowitz is offered a chance to go back to space and Bernadette struggles with whether or not to encourage him.'},
#  {'id': 3064,
#   'season': 7,
#   'episode': 17,
#   'name': 'The Friendship Turbulence',
#   'summary': 'After the insults fly, Bernadette tries to broker the peace between Wolowitz and Sheldon. Meanwhile, Penny is offered an embarrassing movie role and Raj asks Amy to write to a woman on his behalf.'},
#  {'id': 3065,
#   'season': 7,
#   'episode': 18,
#   'name': 'The Mommy Observation',
#   'summary': "When Sheldon visits his Mom in Houston, he is forced to confront a new reality. Meanwhile, Raj's 'Murder Mystery' party starts some fights within the gang."},
#  {'id': 3066,
#   'season': 7,
#   'episode': 19,
#   'name': 'The Indecision Amalgamation',
#   'summary': 'While Raj is wracked with guilt when he tries to date two women at once, Penny wrestles with whether to take a role in a cheesy movie and Sheldon is torn trying to choose between two gaming systems.'},
#  {'id': 3067,
#   'season': 7,
#   'episode': 20,
#   'name': 'The Relationship Diremption',
#   'summary': "Sheldon faces a personal crisis after deciding he's wasting his time with string theory. Meanwhile, a double date between Raj, Emily and the Wolowitzes ends in embarrassment for Howard."},
#  {'id': 3068,
#   'season': 7,
#   'episode': 21,
#   'name': 'The Anything Can Happen Recurrence',
#   'summary': "When Sheldon tries to be spontaneous, it leads to unexpected friction between Penny, Amy and Bernadette. Meanwhile, Raj seeks Howard's help in preparing for a date with Emily."},
#  {'id': 3069,
#   'season': 7,
#   'episode': 22,
#   'name': 'The Proton Transmogrification',
#   'summary': 'Professor Proton helps Sheldon cope with grief, while Leonard turns a relationship milestone into a competition with Penny. Meanwhile, Amy and Bernadette make a "Star Wars Day" gift for the guys.'},
#  {'id': 3070,
#   'season': 7,
#   'episode': 23,
#   'name': 'The Gorilla Dissolution',
#   'summary': 'Bad day causes Penny to reevaluate her life choices - including Leonard. Meanwhile, Howard and Bernadette struggle to care for Mrs. Wolowitz, and Raj gets relationship advice from Sheldon.'},
#  {'id': 3071,
#   'season': 7,
#   'episode': 24,
#   'name': 'The Status Quo Combustion',
#   'summary': "Sheldon is forced to confront an uncertain future and considers a major move. Meanwhile, Raj and Emily take it to the next level, and Mrs. Wolowitz's injury is a major headache for Howard and Bernadette."},
#  {'id': 3072,
#   'season': 8,
#   'episode': 1,
#   'name': 'The Locomotion Interruption',
#   'summary': "Leonard and Amy take an unexpected road trip to Arizona to pick up Sheldon. Meanwhile, Penny interviews for a job at Bernadette's company, and Howard is weirded out by Stuart's relationship with Mrs. Wolowitz."},
#  {'id': 3073,
#   'season': 8,
#   'episode': 2,
#   'name': 'The Junior Professor Solution',
#   'summary': 'Sheldon is ordered to teach a class, and the gang is surprised when Howard signs up to take it; and tensions between Penny and Bernadette afford Amy an opportunity to play one against the other.'},
#  {'id': 3074,
#   'season': 8,
#   'episode': 3,
#   'name': 'The First Pitch Insufficiency',
#   'summary': 'Wolowitz is nervous after NASA asks him to throw out the first pitch at a Los Angeles Angels game. Meanwhile, Leonard and Penny try to prove Sheldon wrong after he says that he and Amy are a "superior couple".'},
#  {'id': 7913,
#   'season': 8,
#   'episode': 4,
#   'name': 'The Hook-Up Reverberation',
#   'summary': "Raj's honesty about his past comes back to haunt him after his girlfriend, Emily, is cold to Penny. Also, the guys consider becoming part-owners in Stuart's comic book store."},
#  {'id': 11229,
#   'season': 8,
#   'episode': 5,
#   'name': 'The Focus Attentuation',
#   'summary': 'Amy and Bernadette accuse Penny of being a "buzzkill" after she gets an email from work during their Vegas weekend. Meanwhile, the guys try to invent something cool, but only come up with new ways to procrastinate.'},
#  {'id': 13149,
#   'season': 8,
#   'episode': 6,
#   'name': 'The Expedition Approximation',
#   'summary': 'Sheldon and Raj test whether they could survive a dark-matter research expedition in a salt mine by simulating the conditions in a steam tunnel. Meanwhile, Leonard and Penny seek advice from Wolowitz and Bernadette after they fight about money.'},
#  {'id': 31863,
#   'season': 8,
#   'episode': 7,
#   'name': 'The Misinterpretation Agitation',
#   'summary': 'The guys try to help Penny out of an awkward work dilemma. Meanwhile, Amy and Bernadette argue over whether or not female scientists should play up their sexuality.'},
#  {'id': 14873,
#   'season': 8,
#   'episode': 8,
#   'name': 'The Prom Equivalency',
#   'summary': "When the gang recreates a high school prom on the roof the of the guys' apartment building, Sheldon feels pressure to participate in all the typical romantic traditions."},
#  {'id': 39636,
#   'season': 8,
#   'episode': 9,
#   'name': 'The Septum Deviation',
#   'summary': "When Leonard gets minor surgery on his nose, Sheldon is the one in need of sympathy. Meanwhile, Raj's parents' impending divorce causes Howard and Bernadette to work on their own marriage."},
#  {'id': 40995,
#   'season': 8,
#   'episode': 10,
#   'name': 'The Champagne Reflection',
#   'summary': 'Sheldon says a tearful goodbye to "Fun with Flags." Also, Leonard, Howard and Raj look for something significant in a dead professor\'s research, and Bernadette is shocked to learn her co-workers\' true feelings from Penny.'},
#  {'id': 50184,
#   'season': 8,
#   'episode': 11,
#   'name': 'The Clean Room Infiltration',
#   'summary': 'On Christmas Eve, Amy plans a traditional Victorian dinner, while Raj, Leonard and Howard scramble to remove a pigeon that flew into the clean room at the university. To prove a point to Amy, a Scrooge-like Sheldon buys her the worst possible gift.'},
#  {'id': 60532,
#   'season': 8,
#   'episode': 12,
#   'name': 'The Space Probe Disintegration',
#   'summary': 'Wolowitz tries to distract Raj, who is anxiously awaiting data from a space probe he helped launch. Meanwhile, Sheldon and Leonard go dress shopping with Penny and Amy.'},
#  {'id': 93521,
#   'season': 8,
#   'episode': 13,
#   'name': 'The Anxiety Optimization',
#   'summary': 'The gang tries to help Sheldon when he becomes stuck in a rut at work by increasing his anxiety level. Howard teases Raj with a new game called "Cinnamon or Emily?"'},
#  {'id': 124086,
#   'season': 8,
#   'episode': 14,
#   'name': 'The Troll Manifestation',
#   'summary': "After Leonard and Sheldon co-publish a physics paper, they must defend themselves against criticism from an online bully. Also, girls' night finds Penny, Amy and Bernadette confronting embarrassing moments from their past."},
#  {'id': 124087,
#   'season': 8,
#   'episode': 15,
#   'name': 'The Comic Book Store Regeneration',
#   'summary': 'Wolowitz receives some shocking news as everyone prepares for the reopening of Stuart\'s comic book store. Penny teaches Sheldon how to "let it go," but can\'t follow her own advice after she learns something infuriating about Amy. Also, Leonard and Raj think they spot Nathan Fillion at a restaurant.'},
#  {'id': 124088,
#   'season': 8,
#   'episode': 16,
#   'name': 'The Intimacy Acceleration',
#   'summary': 'As a joke, Sheldon and Penny try an experiment designed to make participants fall in love. Also, Leonard, Amy, Raj and Emily spend the evening trying to escape a room with a "zombie." And, after returning from Mrs. Wolowitz\' funeral, Bernadette and Howard run into trouble at the airport.'},
#  {'id': 140767,
#   'season': 8,
#   'episode': 17,
#   'name': 'The Colonization Application',
#   'summary': 'Trouble arises when Amy learns Sheldon has applied for a one-way mission to colonize Mars. Also, a trip to the pet store ends in a fight for Sheldon and Amy, Leonard surprises Penny with a very "adult" purchase, and, Raj is caught snooping in Emily\'s apartment.'},
#  {'id': 141514,
#   'season': 8,
#   'episode': 18,
#   'name': 'The Leftover Thermalization',
#   'summary': "Friction ensues when a magazine fails to mention Leonard in an article about the paper he co-wrote with Sheldon. Also, a blackout at Mrs. Wolowitz's home leads to a final family dinner in her honor."},
#  {'id': 150779,
#   'season': 8,
#   'episode': 19,
#   'name': 'The Skywalker Incursion',
#   'summary': 'When Leonard and Sheldon are invited to speak at UC Berkeley, they take a detour to try to meet an idol. Also, when Bernadette and Howard battle over the fate of his Dr. Who TARDIS, Raj and Amy offer to settle the dispute with a game of ping pong.'},
#  {'id': 150780,
#   'season': 8,
#   'episode': 20,
#   'name': 'The Fortification Implementation',
#   'summary': "When Sheldon and Amy build a blanket fort, they come to major crossroads in their relationship. Also, Wolowitz meets the half-brother he never knew he had, and when Penny is invited to appear on Wil Wheaton's podcast, she and Leonard have a huge, on-air argument."},
#  {'id': 151474,
#   'season': 8,
#   'episode': 21,
#   'name': 'The Communication Deterioration',
#   'summary': 'When Raj is asked to create a message in case a NASA mission discovers alien life, the guys fight over what he should do. Also, Penny is torn between auditioning for a movie or keeping her successful pharmaceutical sales job.'},
#  {'id': 151475,
#   'season': 8,
#   'episode': 22,
#   'name': 'The Graduation Transmission',
#   'summary': "Wolowitz questions his engineering abilities when he and Sheldon can't get a toy drone to fly. Meanwhile, a cancelled flight nearly prevents Leonard from giving the commencement address at his former high school, and Raj pits his parents against each other when his father cuts him off financially."},
#  {'id': 151476,
#   'season': 8,
#   'episode': 23,
#   'name': 'The Maternal Combustion',
#   'summary': 'Personalities collide when Sheldon and Leonard\'s mothers finally meet. Meanwhile, Howard finally decides to "man up" and do his fair share of the housework - but not without a little help from his friends.'},
#  {'id': 151477,
#   'season': 8,
#   'episode': 24,
#   'name': 'The Commitment Determination',
#   'summary': 'In the Season 8 finale, Leonard and Penny are pressured to set a wedding date by Sheldon, whose relationship with Amy has taken an interesting turn.'},
#  {'id': 167439,
#   'season': 9,
#   'episode': 1,
#   'name': 'The Matrimonial Momentum',
#   'summary': "After driving to Vegas to get married, Penny struggles with Leonard's confession that he kissed another girl. Also, Sheldon doesn't know how to act after Amy pushes pause on their relationship."},
#  {'id': 206088,
#   'season': 9,
#   'episode': 2,
#   'name': 'The Separation Oscillation',
#   'summary': 'Leonard confronts the woman he kissed on the North Sea in an attempt to set Penny\'s mind at ease. Also, Sheldon films a special episode of "Fun with Flags" after his breakup with Amy, and Bernadette feels guilty about withholding a secret from Penny.'},
#  {'id': 208295,
#   'season': 9,
#   'episode': 3,
#   'name': 'The Bachelor Party Corrosion',
#   'summary': 'The guys surprise Leonard with a belated bachelor-party weekend in Mexico, but their plans hit a bump in the road when they get a flat tire on the way. Meanwhile, the girls lean on Penny to tell her unsuspecting family that she and Leonard eloped.'},
#  {'id': 228310,
#   'season': 9,
#   'episode': 4,
#   'name': 'The 2003 Approximation',
#   'summary': 'Sheldon learns of an impending change in his living arrangements and decides to revert back to 2003, a simpler time before he met Leonard and Penny. Also, Howard and Raj form a band to play at the Comic Book Store.'},
#  {'id': 252299,
#   'season': 9,
#   'episode': 5,
#   'name': 'The Perspiration Implementation',
#   'summary': 'The guys take a fencing lesson from Barry Kripke and Sheldon finds himself in an awkward position when Kripke expresses interest in Amy. Also, when Stuart struggles to get female customers at the Comic Book Store, Penny, Amy and Bernadette come by to help him out.'},
#  {'id': 353007,
#   'season': 9,
#   'episode': 6,
#   'name': 'The Helium Insufficiency',
#   'summary': "In the midst of a nation-wide helium shortage, Sheldon and Leonard take desperate measures to get the supplies they need. Also, Penny and Bernadette download a dating app on Amy's phone to try and find her a new man."},
#  {'id': 321678,
#   'season': 9,
#   'episode': 7,
#   'name': 'The Spock Resonance',
#   'summary': 'While being interviewed for a documentary about Spock from "Star Trek", Sheldon struggles to suppress his emotions about his recent break-up with Amy. Also, Wolowitz and Bernadette butt heads over remodeling his childhood home.'},
#  {'id': 398404,
#   'season': 9,
#   'episode': 8,
#   'name': 'The Mystery Date Observation',
#   'summary': 'When Leonard, Penny and Bernadette learn that Amy is going out on a dinner date, the trio set out to spy on her and the guy. Meanwhile, Sheldon recruits Raj and Howard to find a woman for him, since they were responsible for getting Amy and him together.'},
#  {'id': 409180,
#   'season': 9,
#   'episode': 9,
#   'name': 'The Platonic Permutation',
#   'summary': 'Sheldon and Amy try hanging out as friends when they spend Thanksgiving together at the aquarium. Also, Wolowitz reluctantly agrees to volunteer at the soup kitchen with Bernadette, Raj and Emily, and Penny discovers that Leonard knows more about her than she thought.'},
#  {'id': 466109,
#   'season': 9,
#   'episode': 10,
#   'name': 'The Earworm Reverberation',
#   'summary': 'Sheldon has a revelation when he realizes why a song was stuck in his head. Also, Amy invites Dave over for dinner despite their previously awkward date, and Wolowitz and Koothrappali become obsessed with a fan of their band, "Footprints on the Moon".'},
#  {'id': 478687,
#   'season': 9,
#   'episode': 11,
#   'name': 'The Opening Night Excitation',
#   'summary': "As the guys prepare to go to the premiere of the new Star Wars movie, Sheldon plans a special event for Amy's birthday. Also, Leonard, Wolowitz, and Koothrappali must decide who will take their extra Star Wars movie ticket."},
#  {'id': 529350,
#   'season': 9,
#   'episode': 12,
#   'name': 'The Sales Call Sublimation',
#   'summary': "Penny gets more than she bargained for when Leonard agrees to meet with a psychiatrist on her behalf. Also, Sheldon and Koothrappali collaborate on an astronomical discovery, and Wolowitz and Bernadette can't believe what they are feeling after Stuart moves out."},
#  {'id': 536858,
#   'season': 9,
#   'episode': 13,
#   'name': 'The Empathy Optimization',
#   'summary': 'After having to deal with a sick Sheldon, Leonard, Penny and the gang try to treat themselves to a Sheldon-free weekend.'},
#  {'id': 569144,
#   'season': 9,
#   'episode': 14,
#   'name': 'The Meemaw Materialization',
#   'summary': "Sheldon's thrilled when his Meemaw comes to visit, but his excitement quickly fades when she butts heads with Amy. Also, Raj meets a new girl at the comic book store who makes him question his relationship with Emily."},
#  {'id': 579822,
#   'season': 9,
#   'episode': 15,
#   'name': 'The Valentino Submergence',
#   'summary': "Sheldon and Amy host a live Valentine's Day episode of Fun with Flags, Leonard and Penny grapple with getting older, Howard and Bernadette find a surprise in their hot tub and Raj is torn between Emily and the cute girl he met at the Comic Bookstore."},
#  {'id': 599948,
#   'season': 9,
#   'episode': 16,
#   'name': 'The Positive Negative Reaction',
#   'summary': "When the gang finds out about Bernadette's pregnancy, they celebrate by singing karaoke. Also, Bernadette is concerned when Wolowitz freaks out over her pregnancy announcement, and Wolowitz is convinced he must make more money to provide for the baby."},
#  {'id': 604630,
#   'season': 9,
#   'episode': 17,
#   'name': 'The Celebration Experimentation',
#   'summary': "After more than nine years together, the gang finally celebrates Sheldon's birthday, surprising him with a special guest."}]

# %% [markdown]
# Lets proceed by indexing the documents. The following gathers all the code together. We begin by importing the functions `connect_redis`, `create_index` and `index_documents` from the file `redis_service`.

# %% [markdown]
# Next, we define some variables such as `index_name` (the name of the index), `doc_prefix` (the prefix for the document keys). In addition to that, `season` and `episode` are defined as a `NumericField`, while `name` and `summary` as a `TextField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import json
import redis
from redis.commands.search.field import TextField, NumericField
from redis_service import connect_redis, create_index, index_documents

#Define variables
index_name = 'idx:bibbang' #the name of the index, which you will use when doing queries
doc_prefix = 'bibbang_episode:' #prefix for the document keys

# Define RediSearch fields
season = NumericField(name="season")
episode = NumericField(name="episode")
name = TextField(name="name")
summary = TextField(name="summary")

fields = [season, episode, name, summary]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, ldocs)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# The following enables one to search for the term `rivalry` in the field `summary`. We can use the method `Query` or simply not use it (as we have done before).

# %%
from redis.commands.search.query import Query

#  search a specific field
results = r.ft(index_name).search(Query('@summary:rivalry'))
results
# Out:
# Result{1 total, docs: [Document {'id': 'bibbang_episode:35', 'payload': None, 'summary': 'Penny develops a rivalry with a sexy female neighbor who threatens to become "The New Penny" in the building.', 'name': 'The Dead Hooker Juxtaposition', 'episode': '19', 'season': '2'}]}

# %% [markdown]
# Delete all the data and indexes. To do that, we should import the function `drop_data` and `connect_redis` from the `redis_service` file.

# %%
from redis_service import drop_data, connect_redis

r = connect_redis()
index_name = 'idx:bibbang'
drop_data(r, index_name)
# Out:
# Index and data dropped

# %% [markdown]
# ###### Publico

# %% [markdown]
# In the following exercise we aim to make use of the [TLS-Covid19](https://github.com/LIAAD/tls-covid19) dataset which has the key moments of the [liveblog](https://www.publico.pt/coronavirus-ao-minuto) of the Jornal Público dedicated to Covid.

# %% [markdown]
# First, we begin by loading the file into memory:

# %%
import json
with open("data/publico_km.json", "r",encoding="utf8") as readfile:
    KeyMoments = json.load(readfile)

print(KeyMoments[:1])
# Out:
# [{'source': 'publico', 'lan': 'pt', 'topic': 'açores', 'date': '2020-03-16', 'title': 'Casos confirmados em Portugal: 331, mais 86 do que ontem', 'news': 'Há 331 casos confirmados de infecção pelo novo coronavírus em Portugal, anunciou a Direcção-Geral da Saúde no boletim epidemiológico desta segunda-feira. São mais 86 casos do que no domingo. Há 374 casos que aguardam resultado laboratorial e três pessoas já recuperaram. Ao todo, desde 1 de Janeiro de 2020, houve 2908 casos suspeitos, sendo que 2203 não se confirmaram. Há 4592 pessoas em vigilância pelas autoridades. A região de Lisboa e Vale do Tejo regista 142 casos e o Norte tem 138 casos de infecção. No centro há 31 casos, no Algarve são 13 e nos Açores há um caso registado. Há ainda cinco pessoas infectadas com residência no estrangeiro. Dos casos confirmados, 139 estão em internamento e 18 deles em cuidados intensivos. Há 77 pessoas infectadas que têm mais de 70 anos. A maior parte das pessoas infectadas apresentava tosse (53%), e havia também quem tivesse febre (31%), cefaleia (19%), dores musculares (18%) e fraqueza generalizada (13%). Só em 9% dos casos houve dificuldades a respirar. Há 18 cadeias de transmissão activas, com casos importados sobretudo de Espanha (16), Itália (14), França (nove) e Suíça (cinco); os outros casos importados são de Andorra, Bélgica, Alemanha e Áustria.', 'url': 'https://www.publico.pt/2020/03/16/sociedade/noticia/coronavirus-portugal-meio-gas-europa-comeca-fechar-portas-1907902#36451'}]

# %% [markdown]
# Lets proceed by indexing the documents. The following gathers all the code together. We begin by importing the functions `connect_redis`, `create_index` and `index_documents` from the file `redis_service`.

# %% [markdown]
# Next, we define some variables such as `index_name` (the name of the index), `doc_prefix` (the prefix for the document keys). In addition to that, `source`, `lan`, `topic`, `date`, `title`, `news` and `url` are defined as a `TextField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import json
import redis
from redis.commands.search.field import TextField, NumericField
from redis_service import connect_redis, create_index, index_documents

#Define variables
index_name = 'idx:tlscovid' #the name of the index, which you will use when doing queries
doc_prefix = 'tlscovid_news:' #prefix for the document keys

# Define RediSearch fields
source = TextField(name="source")
lan = TextField(name="lan")
topic = TextField(name="topic")
date = TextField(name="date")
title = TextField(name="title")
news = TextField(name="news")
url = TextField(name="url")

fields = [source, lan, topic, date, title, news, url]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, KeyMoments)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# Lets now search for a specific topic:

# %%
from redis.commands.search.query import Query

#  search a specific field
results = r.ft(index_name).search(Query('@topic:estado de emergência'))
results
# Out:
# %% [markdown]
# Delete all the data and indexes. To do that, we should import the function `drop_data` and `connect_redis` from the `redis_service` file.

# %%
from redis_service import drop_data, connect_redis

r = connect_redis()
index_name = 'idx:tlscovid'
drop_data(r, index_name)
# Out:
# Index and data dropped

# %% [markdown]
# #### Vector Similarity Search

# %% [markdown]
# Vectors (also called `Embeddings`), represent an AI model’s impression (or understanding) of a piece of unstructured data like text, images, audio, videos, etc. Vector Similarity Search (VSS) is the process of finding vectors in the vector database that are similar to a given query vector. Popular VSS uses include recommendation systems, image and video search, document retrieval, and question answering.

# %% [markdown]
# Let's start by having a look at this article before we proceed: https://towardsdatascience.com/text-embeddings-comprehensive-guide-afd97fce8fb5

# %% [markdown]
# ##### Indexing

# %% [markdown]
# Let's start by defining some dummy data related to some wikipedia pages that we want to index.

# %%
ListOfContents = [
    {"title": "Wuhan", "url": "https://en.wikipedia.org/wiki/Wuhan"},
    {"title": "Coronavirus", "url": "https://en.wikipedia.org/wiki/Coronavirus"},
    {"title": "Vaccine", "url": "https://en.wikipedia.org/wiki/COVID-19_vaccine"},
]

# %% [markdown]
# Next, we define a fake embedding for each of the titles and keep them in a new column named `title_emb`.

# %%
import numpy as np

for content in ListOfContents:
    content['title_emb'] = np.random.rand(756)

ListOfContents
# Out:
# [{'title': 'Wuhan',
#   'url': 'https://en.wikipedia.org/wiki/Wuhan',
#   'title_emb': array([0.26476474, 0.03494731, 0.46133644, 0.63578759, 0.64379061,
#          0.1516129 , 0.02328429, 0.92804495, 0.26329111, 0.05996297,
#          0.93158734, 0.69460142, 0.80323076, 0.9807475 , 0.73596734,
#          0.65883485, 0.15178208, 0.59199471, 0.5707369 , 0.47087485,
#          0.07506926, 0.77867708, 0.14370539, 0.88193974, 0.60936737,
#          0.05293196, 0.02584776, 0.23669815, 0.45121482, 0.07033002,
#          0.32663658, 0.85945235, 0.47134091, 0.85438332, 0.97544823,
#          0.80731569, 0.58249987, 0.88865759, 0.06275894, 0.24775087,
#          0.01722549, 0.86058992, 0.09598733, 0.53194645, 0.62118311,
#          0.27004061, 0.20962549, 0.30708404, 0.99776314, 0.08239785,
#          0.27000911, 0.8764186 , 0.13834048, 0.58162504, 0.38985167,
#          0.28521593, 0.55102135, 0.91582637, 0.60243096, 0.46034414,
#          0.26234903, 0.38951087, 0.97117329, 0.85946471, 0.92683812,
#          0.19709135, 0.09018869, 0.51964715, 0.17913211, 0.96869277,
#          0.54754921, 0.70584428, 0.91550979, 0.31589152, 0.07717369,
#          0.84151743, 0.52562558, 0.09117278, 0.69301382, 0.34977848,
#          0.23167506, 0.51583171, 0.88063443, 0.186878  , 0.55936245,
#          0.82043353, 0.74879319, 0.04451152, 0.96609971, 0.83041022,
#          0.6337043 , 0.39471902, 0.88902041, 0.85509206, 0.42658495,
#          2.67153632e-01, 1.87840354e-01, 3.99658039e-01, 1.47757206e-01,
#          8.44094781e-01, 4.26122778e-01, 6.55539734e-01, 2.80314435e-01,
#          1.64865229e-01, 1.10670189e-01, 1.42208301e-01, 3.80267536e-01,
#          1.76873350e-01, 4.46063706e-01, 6.61302891e-01, 7.22200531e-01,
#          7.00535801e-01, 6.43065730e-02, 6.90314100e-01, 4.89592963e-01])}]

# %% [markdown]
# Next, we define the `index_documents` function, which is slightly different than the one we have defined on the `redis_service` file, as in this case we need to create byte vectors for the embeddings.
#
# Looking into the function one can observe that each `doc` of the list of `documents` (`ListOfContents`) is processed individually. All the elements of the `doc`, that is, its `url`, `title` and `title_emb` (the embeddings of the title) are added to the index. However, a special procedure is operated on top of the `title_emb` by converting the array into bytes format.

# %%
import numpy as np

def index_documents(r, doc_prefix, documents, *vector_field):
    for i, doc in enumerate(documents):
        key = f"{doc_prefix}{str(i)}"
        
        for field in vector_field:
            # create byte vectors for item
            text_embedding = np.array(doc[field], dtype=np.float32).tobytes()

             # replace list of floats with byte vectors
            doc[field] = text_embedding
        
        r.hset(key, mapping=doc)
    
    print("Documents indexed")

# %% [markdown]
# Lets proceed by indexing the documents. The following gathers all the code together. We begin by importing the functions `connect_redis` and `create_index` from the file `redis_service`, as the `index_documents` has already been defined above.

# %% [markdown]
# Next, we define some variables such as `index_name` (the name of the index), `doc_prefix` (the prefix for the document keys), `VECTOR_DIM` (which is the dimension of the embeddings of the title, that is 756 in this case), `VECTOR_NUMBER` which is the number of docs to index and `DISTANCE_METRIC` (the similarity measure to evaluate the proximity of the query to the vectors).

# %% [markdown]
# In addition to that, `url`, `title` and `summary` are defined as a `TextField`, while `title_emb` as a `VectorField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import json
import redis
from redis.commands.search.field import TextField, NumericField, VectorField
from redis_service import connect_redis, create_index
import numpy as np

#Define variables
index_name = 'idx:wiki_dummy' #the name of the index, which you will use when doing queries
doc_prefix = 'wiki_dummy:' #prefix for the document keys

# Constants
vector_field = 'title_emb'
VECTOR_DIM = len(ListOfContents[0][vector_field]) # length of the vectors
VECTOR_NUMBER = len(ListOfContents)              # initial number of vectors
DISTANCE_METRIC = "COSINE"                # distance metric for the vectors (ex. COSINE, IP, L2)

# Define RediSearch fields
url = TextField(name="url")
title = TextField(name="title")
title_emb = VectorField(vector_field,
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)

fields = [url, title, title_emb]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, ListOfContents, vector_field)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# You can check the results on redis-insight: http://localhost:8001

# %% [markdown]
# ##### Searching

# %% [markdown]
# You can use VSS queries with the `r.ft(index_name).search` query command. To use a VSS query, you must specify the option `.dialect(2)`.

# %% [markdown]
# There are two supported types of vector queries in Redis: `KNN` and `Range`. `Hybrid` queries can work in both settings and combine elements of traditional search and VSS.

# %% [markdown]
# ###### KNN

# %% [markdown]
# KNN queries are for finding the `top-K` most similar vectors given a query vector. We begin by defining the `search_redis` function. The parameter `hybrid_fields` is to be used in the hybrid type queries.

# %% [markdown]
# Note that we also need an embedding for the query. We will again simulate an embedding using the numpy module. Also note that we make use of the function `connect_redis` from the `redis_service` file.

# %%
import numpy as np
from redis.commands.search.query import Query
from redis_service import connect_redis

def search_redis(index_name, k, vector_field, return_fields, hybrid_fields = "*"):
    
    r = connect_redis()
    
    #get embeddings of a hyphotetical query
    query_emb = np.random.rand(756)
    
    # Prepare the Query
    query = (
        Query(f"{hybrid_fields}=>[KNN {k} @{vector_field} $vector as score]")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {"vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %% [markdown]
# Next, we call the function `search_redis`. We ask the system to retrieve the top-`5` results, to look at the `title_emb` vector_field and to get the fields designated in the `return_fields` variable. Note that we don't have a query as we are simulating this exercise. The fake embedding of the query is defined in the previous function.

# %%
k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "score"]
index_name = 'idx:wiki_dummy' #the name of the index, which you will use when doing queries

results = search_redis(index_name, k, vector_field, return_fields)
for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc.title}; score:{score:.3f}")
    print(f"{doc.url}")
    print("\n")
# Out:
# Vaccine; score:0.754
# https://en.wikipedia.org/wiki/COVID-19_vaccine
#
#
# Wuhan; score:0.750
# https://en.wikipedia.org/wiki/Wuhan
#
#
# Coronavirus; score:0.743
# https://en.wikipedia.org/wiki/Coronavirus

# %% [markdown]
# ###### Range

# %% [markdown]
# Range queries provide a way to filter results by the distance between a vector field in Redis and a query vector based on some pre-defined threshold (radius).

# %% [markdown]
# Once again, we will be simulating an embedding for the hypothetical query. Also note that we make use of the function `connect_redis` from the `redis_service` file.

# %%
import numpy as np
from redis.commands.search.query import Query
from redis_service import connect_redis

def search_redis(index_name, k, vector_field, return_fields, radius):
    r = connect_redis()
    
    #get embeddings of a hyphotetical query
    query_emb = np.random.rand(756)
    
    # Prepare the Query
    query = (
        Query(f"@{vector_field}:[VECTOR_RANGE $radius $vector]=>"+"{$YIELD_DISTANCE_AS: score}")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {
        "radius": radius,
        "vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %%
k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "score"]
index_name = 'idx:wiki_dummy' #the name of the index, which you will use when doing queries
radius = 0.8

results = search_redis(index_name, k, vector_field, return_fields, radius)
for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc.title}; score:{score:.3f}")
    print(f"{doc.url}")
    print("\n")
# Out:
# Coronavirus; score:0.751
# https://en.wikipedia.org/wiki/Coronavirus
#
#
# Wuhan; score:0.749
# https://en.wikipedia.org/wiki/Wuhan
#
#
# Vaccine; score:0.734
# https://en.wikipedia.org/wiki/COVID-19_vaccine

# %% [markdown]
# ###### Hybrid

# %% [markdown]
# Hybrid queries contain both traditional filters (numeric, tags, text) and VSS in one single Redis command.

# %% [markdown]
# Once again, we will be simulating an embedding for the hypothetical query. Also note that we make use of the function `connect_redis` from the `redis_service` file.

# %%
import numpy as np
from redis.commands.search.query import Query
from redis_service import connect_redis
    
def search_redis(index_name, k, vector_field, return_fields, hybrid_fields = "*"):
    r = connect_redis()
    
    #get embeddings of a hyphotetical query
    query_emb = np.random.rand(756)
    
    # Prepare the Query
    query = (
        Query(f"{hybrid_fields}=>[KNN {k} @{vector_field} $vector as score]")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {"vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %% [markdown]
# Note that besides using the VSS feature, we are also restricting the results to those titles that have the word Wuhan in the title field (see hybrid_field variable).

# %%
k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "summary", "score"]
index_name = 'idx:wiki_dummy' #the name of the index, which you will use when doing queries
hybrid_field = f"@title:wuhan"
    
results = search_redis(index_name, k, vector_field, return_fields, hybrid_fields = hybrid_field)
for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc.title}; score:{score:.3f}")
    print(f"{doc.url}")
    print("\n")
# Out:
# Wuhan; score:0.737
# https://en.wikipedia.org/wiki/Wuhan

# %% [markdown]
# Next delete all data and the index. To do that, we should import the function `drop_data` and `connect_redis` from the `redis_service` file.

# %%
from redis_service import drop_data, connect_redis

r = connect_redis()
index_name = 'idx:wiki_dummy'
drop_data(r, index_name)
# Out:
# Index and data dropped

# %% [markdown]
# ##### Quizzes

# %% [markdown]
# ###### Wikipedia (Hugging Face Embeddings)

# %% [markdown]
# In this example, we are going to collect some texts from wikipedia pages related to Covid. For each title and text we aim to obtain a vector of embeddings using the transformer arquitecture from Hugging Face. The core steps are as follows:

# %% [markdown]
# - get the texts from wikipedia
# - Load the pre-trained model and tokenizer.
# - Tokenize your text using the tokenizer.
# - Get the embeddings for your text.

# %% [markdown]
# Lets begin by installing the following python package:

# %%
# !pip install transformers

# %% [markdown]
# You will also need to install PyTorch. To see which instalation best fits your case, please see this webpage: https://pytorch.org/get-started/locally/. Most likely this will be:

# %%
# !pip install torch torchvision torchaudio

# %% [markdown]
# Next, we will define the `get_embeddings_bert` which receives a text and a model name (e.g., bert) and returns the embeddings of the document.

# %%
def get_embeddings_bert(text, model_name):
    from transformers import AutoTokenizer, AutoModel

    # Load a pre-trained model and tokenizer
    model_name = model_name
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    # Tokenize and encode the text
    inputs = tokenizer(text, return_tensors="pt")

    # Get the embeddings
    output = model(**inputs)

    document_embedding = output.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
    return document_embedding

# %% [markdown]
# To get the texts from wikipedia we will need the following python package:

# %%
# !pip install wikipedia

# %% [markdown]
# We will use the following code to extract the url, the title and the summary of the wikipedia texts found within the list (ListWikiPages) and the `get_embeddings_bert` function to get the embeddings for both the title and the summary. Note that bert can only accept 512 tokens (the smallest units into which a text is divided for processing by the model. These tokens are often words, subwords, or even characters). Several techniques exist to consider only 512 tokens. In this case we are using the truncate technique which discard portions of the text to fit within the token limit. For example, you can take the first 500 tokens of the text and disregard the rest. This approach is appropriate when you don't want to lose any information.

# %% [markdown]
# If you need more tokens you may use gpt2 instead of bert model.

# %% [markdown]
# Please note that when you load a pre-trained model from the Hugging Face Transformers library using `AutoModel.from_pretrained(model_name)`, the model is loaded into memory, and it doesn't get saved to a specific file location on your local filesystem.

# %%
import wikipedia

ListWikiPages = ["covid-19", "coronavirus", "COVID-19 pandemic", "symptoms of COVID‑19", 
                 "long COVID", "COVID-19_testing", "COVID-19 vaccines", "Wuhan", "Transmission_of_COVID-19",
                "Variants of SARS-CoV-2"]
model_name = "bert-base-uncased" #gpt2 #bert-base-uncased

ListOfContents = []
for wikipage in ListWikiPages:
    summary = wikipedia.summary(wikipage)
    summary_emb = get_embeddings_bert(summary[:500], model_name)
    page = wikipedia.page(wikipage)
    url = page.url
    title = page.title
    title_emb = get_embeddings_bert(title, model_name)
    ListOfContents.append({'url':url, 'title':title, 'title_emb': title_emb, 'summary':summary, 'summary_emb':summary_emb})
    print(wikipage)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# covid-19
# coronavirus
# COVID-19 pandemic
# symptoms of COVID‑19
# long COVID
# COVID-19_testing
# COVID-19 vaccines
# Wuhan
# Transmission_of_COVID-19
# Variants of SARS-CoV-2

# %% [markdown]
# As this takes some time to be computed, it might be a good idea to make a copy of the object in case something goes wrong.

# %%
ListOfContents1 = ListOfContents[::]

# %% [markdown]
# Next, we define the `index_documents` function, which is slightly different than the one defined on `redis_service` file, as in this case we need to create byte vectors for the embeddings.

# %% [markdown]
# Looking into the function one can observe that each `doc` of the list of `documents` (`ListOfContents`) is processed individually. All the elements of the `doc`, that is, its `summary`, `summary_emb`, `url`, `title` and `title_emb` (the embeddings of the title) are added to the index. However, a special procedure is operated on top of the `title_emb` and of the `summary_emb` by converting the array into bytes format.

# %%
def index_documents(r, doc_prefix, documents, *vector_field):
    for i, doc in enumerate(documents):
        key = f"{doc_prefix}{str(i)}"
        
        for field in vector_field:
            # create byte vectors for item
            text_embedding = np.array(doc[field], dtype=np.float32).tobytes()

             # replace list of floats with byte vectors
            doc[field] = text_embedding
        
        r.hset(key, mapping=doc)
    
    print("Documents indexed")

# %% [markdown]
# Lets proceed by indexing the documents. The following gathers all the code together. We begin by importing the functions `connect_redis` and `create_index` from the file `redis_service`, as the `index_documents` has already been defined above.

# %% [markdown]
# Next, we define some variables such as `index_name` (the name of the index), `doc_prefix` (the prefix for the document keys), `VECTOR_DIM` (which is the dimension of the Bert embeddings of the title, that is 512), `VECTOR_NUMBER` which is the number of docs to index and `DISTANCE_METRIC` (the similarity measure to evaluate the proximity of the query to the vectors).

# %% [markdown]
# In addition to that, `url`, `title` and `summary` are defined as a `TextField`, while `title_emb` as a `VectorField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import redis
from redis.commands.search.field import TextField, NumericField, VectorField
from redis_service import connect_redis, create_index
import json
import numpy as np

#Define variables
index_name = 'idx:wiki_hugging' #the name of the index, which you will use when doing queries
doc_prefix = 'wiki_hugging:' #prefix for the document keys

# Constants
vector_field = 'title_emb'
vector_field1 = "summary_emb"
VECTOR_DIM = len(ListOfContents[0][vector_field]) # length of the vectors
VECTOR_NUMBER = len(ListOfContents)              # initial number of vectors
DISTANCE_METRIC = "COSINE"                # distance metric for the vectors (ex. COSINE, IP, L2)

# Define RediSearch fields
url = TextField(name="url")
title = TextField(name="title")
summary = TextField(name="summary")
title_emb = VectorField(vector_field,
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)
summary_emb = VectorField(vector_field1,
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)

fields = [url, title, title_emb, summary, summary_emb]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, ListOfContents, vector_field, vector_field1)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# You can check the results on redis-insight: http://localhost:8001

# %% [markdown]
# Once we have the docs indexed its time to search for results. We begin by defining the `search_redis` function. Note that we also need an embedding for the query. Also note that we make use of the function `connect_redis` from the `redis_service` file.

# %%
from redis.commands.search.query import Query
from redis_service import connect_redis
import numpy as np
    
def search_redis(query_emb, index_name, k, vector_field, return_fields, hybrid_fields = "*"):
    r = connect_redis()
       
    # Prepare the Query
    query = (
        Query(f"{hybrid_fields}=>[KNN {k} @{vector_field} $vector as score]")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {"vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %% [markdown]
# Next, we call the function `search_redis`. We define the query `wuhan`, ask the system to retrieve the top-`5` results, to look at the `title_emb` vector_field (the other possibility was to look at the `summary_emb`) and to get the fields designated in the `return_fields` variable (note that we are only showing the first 50 chars of the summary for a matter of convenience).

# %%
#variables
q = "wuhan"
model_name = "bert-base-uncased" #gpt2 #bert-base-uncased
#model_name = "neuralmind/bert-base-portuguese-cased" #bertimbau PT

#get embeddings of the query
query_emb = get_embeddings_bert(q, model_name)

k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "summary", "score"]
index_name = 'idx:wiki_hugging' #the name of the index, which you will use when doing queries

results = search_redis(query_emb, index_name, k, vector_field, return_fields)
for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc.title}; score:{score:.3f}")
    print(f"{doc.url}")
    print(f"{doc.summary[:50]}")
    print("\n")
# Out:
# Wuhan; score:1.000
# https://en.wikipedia.org/wiki/Wuhan
# Wuhan is the capital of Hubei Province in the Peop
#
#
# Coronavirus; score:0.517
# https://en.wikipedia.org/wiki/Coronavirus
# Coronaviruses are a group of related RNA viruses t
#
#
# COVID-19 pandemic; score:0.434
# https://en.wikipedia.org/wiki/COVID-19_pandemic
# The COVID-19 pandemic, also known as the coronavir
#
#
# COVID-19 vaccine; score:0.415
# https://en.wikipedia.org/wiki/COVID-19_vaccine
# A COVID‑19 vaccine is a vaccine intended to provid
#
#
# Long COVID; score:0.414
# https://en.wikipedia.org/wiki/Long_COVID
# Long COVID or long-haul COVID is a group of health

# %% [markdown]
# Delete all the data and the index. To do that, we should import the function `drop_data` and `connect_redis` from the `redis_service` file.

# %%
from redis_service import drop_data, connect_redis

r = connect_redis()
index_name = 'idx:wiki_hugging'
drop_data(r, index_name)
# Out:
# Index and data dropped

# %% [markdown]
# ###### Wikipedia (OpenAI Embeddings)

# %% [markdown]
# In this example, we are going to collect some texts from wikipedia pages related to Covid. For each title we aim to obtain a vector of embeddings using the OpenAI API, which requires you to have an API key (you will need a credit card) and to define its key in your environment. You may want to look at this [webpage](https://www.di.ubi.pt/~rcampos/LargeLanguageModels/OpenAI/1GetStarted.ipynb) to know how to get a key from OpenAI.

# %% [markdown]
# Once you have the key, you will be able to proceed as follows:

# %% [markdown]
# - get the texts from wikipedia
# - get the embeddings for your text.

# %% [markdown]
# To get the texts from wikipedia we will need the following python package:

# %%
# !pip install wikipedia

# %% [markdown]
# We will use the following code to extract the url, the title and the summary of the wikipedia texts found within the list (ListWikiPages).

# %%
import wikipedia

ListWikiPages = ["covid-19", "coronavirus", "COVID-19 pandemic", "symptoms of COVID‑19", 
                 "long COVID", "COVID-19_testing", "COVID-19 vaccines", "Wuhan", "Transmission_of_COVID-19",
                "Variants of SARS-CoV-2"]
                 
ListOfContents = []
for wikipage in ListWikiPages:
    summary = wikipedia.summary(wikipage)
    page = wikipedia.page(wikipage)
    url = page.url
    title = page.title
    ListOfContents.append({'url':url, 'title':title, 'summary':summary})

# %% [markdown]
# We proceed by installing the `openai` python package which will enable us to get the embeddings.

# %%
# !pip install openai

# %% [markdown]
# For the embeddings we will be using the [text-embedding-ada-002](https://openai.com/blog/new-and-improved-embedding-model) model, which is the most popular embeddings model of openAI with a price of $0.0001 for 1,000 tokens and 1536 dimensions. Note that the input for api is a list of text(s).

# %%
import openai

def get_embeddings_openai(ListOfTexts, model):
    ListEmb = []
    response = openai.Embedding.create(input=ListOfTexts, model=model)
    for text_emb in response["data"]:
        ListEmb.append(text_emb["embedding"])
    return ListEmb

# %% [markdown]
# Since executing this APIs costs some money, we will be getting embeddings just for the title texts. Note that, as referred before, we are passing for the `get_embeddings` function a list with the titles. We will then iterate over the `ListOfContents` and for each wikipedia page item, add a new field named `title_emb` with the openAI embedding for the title.

# %%
model = "text-embedding-ada-002"
title_emb = get_embeddings_openai([content["title"] for content in ListOfContents], model)

for i, content in enumerate(ListOfContents):
    content['title_emb'] = title_emb[i]

ListOfContents
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/COVID-19',
#   'title': 'COVID-19',
#   'summary': "Coronavirus disease 2019 (COVID-19) is a contagious disease caused by the coronavirus SARS-CoV-2. The first known case was identified in Wuhan, China, in December 2019. The disease quickly spread worldwide, resulting in the ongoing COVID-19 pandemic.\nThe symptoms of COVID‑19 are variable but often include fever, fatigue, cough, breathing difficulties, loss of smell, and loss of taste. Symptoms may begin one to fourteen days after exposure to the virus. At least a third of people who are infected do not develop noticeable symptoms. Of those who develop symptoms noticeable enough to be classified as patients, most (81%) develop mild to moderate symptoms (up to mild pneumonia), while 14% develop severe symptoms (dyspnea, hypoxia, or more than 50% lung involvement on imaging), and 5% develop critical symptoms (respiratory failure, shock, or multiorgan dysfunction). Older people are at a higher risk of developing severe symptoms. Some complications result in death. Some people continue to experience a range of effects (long COVID) for months or years after infection, and damage to organs has been observed. Multi-year studies are underway to further investigate the long-term effects of the disease.COVID‑19 transmission occurs when infectious particles are breathed in or come into contact with the eyes, nose, or mouth. The risk is highest when people are in close proximity, but small airborne particles containing the virus can remain suspended in the air and travel over longer distances, particularly indoors. Transmission can also occur when people touch their eyes, nose or mouth after touching surfaces or objects that have been contaminated by the virus. People remain contagious for up to 20 days and can spread the virus even if they do not develop symptoms.Testing methods for COVID-19 to detect the virus's nucleic acid include real-time reverse transcription polymerase chain reaction (RT‑PCR), transcription-mediated amplification, and reverse transcription loop-mediated isothermal amplification (RT‑LAMP) from a nasopharyngeal swab.Several COVID-19 vaccines have been approved and distributed in various countries, many of which have initiated mass vaccination campaigns. Other preventive measures include physical or social distancing, quarantining, ventilation of indoor spaces, use of face masks or coverings in public, covering coughs and sneezes, hand washing, and keeping unwashed hands away from the face. While drugs have been developed to inhibit the virus, the primary treatment is still symptomatic, managing the disease through supportive care, isolation, and experimental measures.",
#   'title_emb': [0.0015133687993511558,
#    -0.013100174255669117,
#    -0.0026534670032560825,
#    -0.028926847502589226,
#    -0.012087475508451462,
#    0.013866190798580647,
#    -0.013002799823880196,
#    0.008465128019452095,
#    -0.011964133940637112,
#    -0.0006081876344978809,
#    0.007504361681640148,
#    0.0021097902208566666,
#    -0.024460583925247192,
#    0.005595813039690256,
#    -0.006829228717833757,
#    -0.0037391975056380033,
#    0.03419807553291321,
#    -0.022448167204856873,
#    0.013437740504741669,
#    -0.011574633419513702,
#    -0.02781028114259243,
#    0.03141964599490166,
#    0.005027792416512966,
#    -0.016735505312681198,
#    -0.003430843586102128,
#    0.01794295385479927,
#    -0.006410516332834959,
#    -0.035989776253700256,
#    -0.0003339148825034499,
#    -0.019072502851486206,
#    0.015839656814932823,
#    -0.016553739085793495,
#    -0.0179689209908247,
#    0.005407554563134909,
#    0.004164401441812515,
#    -0.009302551858127117,
#    0.0031500791665166616,
#    -0.015748772770166397,
#    0.013853207230567932,
#    -0.020137136802077293,
#    0.028615247458219528,
#    0.027109181508421898,
#    -0.014826956205070019,
#    0.0012220554053783417,
#    -0.008393718861043453,
#    0.0010200024116784334,
#    -0.004988842643797398,
#    -0.017086055129766464,
#    -0.017501521855592728,
#    0.008510569110512733,
#    0.02705724909901619,
#    0.008925423957407475,
#    -0.001222276478074491,
#    0.008072635158896446,
#    -0.02677627094089985,
#    -0.029135866090655327,
#    -0.015965735539793968,
#    0.005953488405793905,
#    0.011381197720766068,
#    0.0014330691192299128,
#    0.00099946151021868,
#    -0.013593317940831184,
#    0.01420886442065239,
#    0.016850585117936134,
#    -0.03562474995851517,
#    -0.0012671600561589003,
#    -0.004446682054549456,
#    -0.004052347503602505,
#    -0.009944922290742397,
#    0.003702896647155285,
#    -0.016555635258555412,
#    0.022788042202591896,
#    -0.01606832817196846,
#    0.007501972373574972,
#    -0.007316025905311108,
#    0.0075083845295012,
#    0.013157305307686329,
#    0.02004373073577881,
#    -0.005895780865103006,
#    0.012118570506572723,
#    0.0014042153488844633,
#    -0.018350979313254356,
#    -0.010804122313857079,
#    0.000656422576867044,
#    ...]}]

# %% [markdown]
# Next, we define the `index_documents` function, which is slightly different than the one defined on `redis_service` file, as in this case we need to create byte vectors for the embeddings.

# %% [markdown]
# Looking into the function one can observe that each `doc` of the list of `documents` (`ListOfContents`) is processed individually. All the elements of the `doc`, that is, its `url`, `summary`, `title` and `title_emb` (the embeddings of the title) are added to the index. However, a special procedure is operated on top of the `title_emb` by converting the array into bytes format.

# %%
import numpy as np

def index_documents(r, doc_prefix, documents, *vector_field):
    for i, doc in enumerate(documents):
        key = f"{doc_prefix}{str(i)}"
        
        for field in vector_field:
            # create byte vectors for item
            text_embedding = np.array(doc[field], dtype=np.float32).tobytes()

             # replace list of floats with byte vectors
            doc[field] = text_embedding
        
        r.hset(key, mapping=doc)
    
    print("Documents indexed")

# %% [markdown]
# Lets proceed by indexing the documents. The following gathers all the code together. We begin by importing the functions `connect_redis` and `create_index` from the file `redis_service`, as the `index_documents` has already been defined above.

# %% [markdown]
# Next, we define some variables such as `index_name` (the name of the index), `doc_prefix` (the prefix for the document keys), `VECTOR_DIM` (which is the dimension of the openAI embeddings of the title, that is 1536), `VECTOR_NUMBER` which is the number of docs to index and `DISTANCE_METRIC` (the similarity measure to evaluate the proximity of the query to the vectors).

# %% [markdown]
# In addition to that, `url`, `title` and `summary` are defined as a `TextField`, while `title_emb` as a `VectorField`. Finally `fields` specifies the set of fields to be indexed.

# %%
import redis
from redis.commands.search.field import TextField, NumericField, VectorField
from redis_service import connect_redis, create_index
import json
import numpy as np

#Define variables
index_name = 'idx:wiki_openai' #the name of the index, which you will use when doing queries
doc_prefix = 'wiki_openai:' #prefix for the document keys

# Constants
vector_field = 'title_emb'
VECTOR_DIM = len(ListOfContents[0][vector_field]) # length of the vectors
VECTOR_NUMBER = len(ListOfContents)              # initial number of vectors
DISTANCE_METRIC = "COSINE"                # distance metric for the vectors (ex. COSINE, IP, L2)

# Define RediSearch fields
url = TextField(name="url")
title = TextField(name="title")
summary = TextField(name="summary")
title_emb = VectorField(vector_field,
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)

fields = [url, title, title_emb, summary]

r = connect_redis()
create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, ListOfContents, vector_field)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# You can check the results on redis-insight: http://localhost:8001

# %% [markdown]
# Once we have the docs indexed its time to search for results. We begin by defining the `search_redis` function. Also note that we make use of the function `connect_redis` from the `redis_service` file.

# %% [markdown]
# Note that for the query `q` we need to get its embedding by passing it as a list (that is the reason why we have `[q]`). From the retrieved results of the openAI API we then want to keep only the embedding (that is reason to have `[0]["embedding"]`)

# %%
from redis.commands.search.query import Query
from redis_service import connect_redis
import numpy as np

def search_redis(query_emb, index_name, k, vector_field, return_fields, hybrid_fields = "*"):
    r = connect_redis()

    # Prepare the Query
    query = (
        Query(f"{hybrid_fields}=>[KNN {k} @{vector_field} $vector as score]")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {"vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %% [markdown]
# Next, we call the function `search_redis`. We define the query `wuhan`, ask the system to retrieve the top-`5` results, to look at the `title_emb` vector_field and to get the fields designated in the `return_fields` variable (note that we are only showing the first 50 chars of the summary for a matter of convenience).

# %%
#variables
q = "wuhan"
model = "text-embedding-ada-002"

#get embeddings of the query
query_emb = get_embeddings_openai([q], model)[0]

k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "summary", "score"]
index_name = 'idx:wiki_openai' #the name of the index, which you will use when doing queries

results = search_redis(query_emb, index_name, k, vector_field, return_fields)
for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc.title}; score:{score:.3f}")
    print(f"{doc.url}")
    print(f"{doc.summary[:50]}")
    print("\n")
# Out:
# Wuhan; score:0.961
# https://en.wikipedia.org/wiki/Wuhan
# Wuhan is the capital of Hubei Province in the Peop
#
#
# COVID-19; score:0.826
# https://en.wikipedia.org/wiki/COVID-19
# Coronavirus disease 2019 (COVID-19) is a contagiou
#
#
# Coronavirus; score:0.824
# https://en.wikipedia.org/wiki/Coronavirus
# Coronaviruses are a group of related RNA viruses t
#
#
# COVID-19 pandemic; score:0.815
# https://en.wikipedia.org/wiki/COVID-19_pandemic
# The COVID-19 pandemic, also known as the coronavir
#
#
# COVID-19 testing; score:0.801
# https://en.wikipedia.org/wiki/COVID-19_testing
# COVID-19 testing involves analyzing samples to ass

# %% [markdown]
# Delete all the data and the index. To do that, we should import the function `drop_data` and `connect_redis` from the `redis_service` file.

# %%
from redis_service import drop_data, connect_redis

r = connect_redis()
index_name = 'idx:_openai'
drop_data(r, index_name)
# Out:
# Index does not exist

# %% [markdown]
# ## Bibliography

# %% [markdown]
# - https://www.analyticsvidhya.com/blog/2022/06/introduction-to-redis-using-python/
# - https://betterprogramming.pub/getting-started-with-redis-a-python-tutorial-3a18531a73a6
# - https://cookbook.openai.com/examples/vector_databases/redis/getting-started-with-redis-and-openai
# - https://redis-py.readthedocs.io/en/stable/examples/search_vector_similarity_examples.html
